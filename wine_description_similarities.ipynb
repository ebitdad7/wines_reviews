# %%
from collections import Counter
import numpy as np
import nltk
import re
import sklearn.manifold
import multiprocessing
import pandas as pd
import gensim.models.word2vec as w2v

# %%
data = pd.read_csv('winemag-data_first150k.csv')

# %%
labels = data['variety']
descriptions = data['description']

# %%
print('{}   :   {}'.format(labels.tolist()[0], descriptions.tolist()[0]))
print('{}   :   {}'.format(labels.tolist()[56], descriptions.tolist()[56]))
print('{}   :   {}'.format(labels.tolist()[93], descriptions.tolist()[93]))
# Out:
# Cabernet Sauvignon   :   This tremendous 100% varietal wine hails from Oakville and was aged over three years in oak. Juicy red-cherry fruit and a compelling hint of caramel greet the palate, framed by elegant, fine tannins and a subtle minty tone in the background. Balanced and rewarding from start to finish, it has years ahead of it to develop further nuance. Enjoy 2022–2030.
# Sauvignon Blanc   :   Delicious while also young and textured, this wine comes from biodynamically grown grapes. It has a strong sense of minerality as well as intense citrus and green fruits. It's tight at the moment and needs to round out, so drink from 2018.
# Chardonnay   :   A smoky scent and earthy, crisp-apple flavors make this medium-bodied wine a change of pace from the average butterball Chardonnay. It has welcome acidity and a nicely smooth texture.

# %%
varietal_counts = labels.value_counts()
print(varietal_counts[:50])
# Out:
# Chardonnay                       14482
# Pinot Noir                       14291
# Cabernet Sauvignon               12800
# Red Blend                        10062
# Bordeaux-style Red Blend          7347
# Sauvignon Blanc                   6320
# Syrah                             5825
# Riesling                          5524
# Merlot                            5070
# Zinfandel                         3799
# Sangiovese                        3345
# Malbec                            3208
# White Blend                       2824
# Rosé                              2817
# Tempranillo                       2556
# Nebbiolo                          2241
# Portuguese Red                    2216
# Sparkling Blend                   2004
# Shiraz                            1970
# Corvina, Rondinella, Molinara     1682
# Rhône-style Red Blend             1505
# Pinot Gris                        1365
# Barbera                           1365
# Cabernet Franc                    1363
# Sangiovese Grosso                 1346
# Pinot Grigio                      1305
# Viognier                          1263
# Bordeaux-style White Blend        1261
# Champagne Blend                   1238
# Port                              1058
# Grüner Veltliner                  1042
# Gewürztraminer                     982
# Portuguese White                   941
# Petite Sirah                       897
# Carmenère                          761
# Tempranillo Blend                  756
# Chenin Blanc                       746
# Glera                              622
# Grenache                           603
# Prosecco                           594
# Albariño                           537
# Gamay                              535
# Pinot Blanc                        470
# Nero d'Avola                       458
# Moscato                            430
# Rhône-style White Blend            409
# Garganega                          402
# Garnacha                           401
# Torrontés                          367
# Dolcetto                           358
# Name: variety, dtype: int64

# %%
corpus_raw = ""
for description in descriptions:
    corpus_raw += description

# %%
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

# %%
raw_sentences = tokenizer.tokenize(corpus_raw)

# %%
def sentence_to_wordlist(raw):
    clean = re.sub("[^a-zA-Z]"," ", raw)
    words = clean.split()
    return words

# %%
sentences = []
for raw_sentence in raw_sentences:
    if len(raw_sentence) > 0:
        sentences.append(sentence_to_wordlist(raw_sentence))

# %%
print(raw_sentences[0])
print(sentence_to_wordlist(raw_sentences[0]))
# Out:
# This tremendous 100% varietal wine hails from Oakville and was aged over three years in oak.
# ['This', 'tremendous', 'varietal', 'wine', 'hails', 'from', 'Oakville', 'and', 'was', 'aged', 'over', 'three', 'years', 'in', 'oak']

# %%
token_count = sum([len(sentence) for sentence in sentences])
print('The wine corpus contains {0:,} tokens'.format(token_count))
# Out:
# The wine corpus contains 6,194,763 tokens

# %%
num_features = 300
min_word_count = 10
num_workers = multiprocessing.cpu_count()
context_size = 10
downsampling = 1e-3
seed=1993

# %%
wine2vec = w2v.Word2Vec(
    sg=1,
    seed=seed,
    workers=num_workers,
    size=num_features,
    min_count=min_word_count,
    window=context_size,
    sample=downsampling
)

# %%
wine2vec.build_vocab(sentences)

# %%
print('Word2Vec vocabulary length:', len(wine2vec.wv.vocab))
# Out:
# Word2Vec vocabulary length: 11379

# %%
wine2vec.wv.vocab
# Out:
# {'This': <gensim.models.keyedvectors.Vocab at 0x1d030ad18c8>,
#  'tremendous': <gensim.models.keyedvectors.Vocab at 0x1d0538f4f88>,
#  'varietal': <gensim.models.keyedvectors.Vocab at 0x1d0538fa108>,
#  'wine': <gensim.models.keyedvectors.Vocab at 0x1d0538fa4c8>,
#  'hails': <gensim.models.keyedvectors.Vocab at 0x1d0538fa5c8>,
#  'from': <gensim.models.keyedvectors.Vocab at 0x1d0538fa648>,
#  'Oakville': <gensim.models.keyedvectors.Vocab at 0x1d0538fa688>,
#  'and': <gensim.models.keyedvectors.Vocab at 0x1d0538fa6c8>,
#  'was': <gensim.models.keyedvectors.Vocab at 0x1d0538fa588>,
#  'aged': <gensim.models.keyedvectors.Vocab at 0x1d0538fa608>,
#  'over': <gensim.models.keyedvectors.Vocab at 0x1d0538fa708>,
#  'three': <gensim.models.keyedvectors.Vocab at 0x1d0538fa748>,
#  'years': <gensim.models.keyedvectors.Vocab at 0x1d0538fa788>,
#  'in': <gensim.models.keyedvectors.Vocab at 0x1d0538fa7c8>,
#  'oak': <gensim.models.keyedvectors.Vocab at 0x1d0538fa808>,
#  'Juicy': <gensim.models.keyedvectors.Vocab at 0x1d0538fa848>,
#  'red': <gensim.models.keyedvectors.Vocab at 0x1d0538fa888>,
#  'cherry': <gensim.models.keyedvectors.Vocab at 0x1d0538fa8c8>,
#  'fruit': <gensim.models.keyedvectors.Vocab at 0x1d0538fa908>,
#  'a': <gensim.models.keyedvectors.Vocab at 0x1d0538fa948>,
#  'compelling': <gensim.models.keyedvectors.Vocab at 0x1d0538fa988>,
#  'hint': <gensim.models.keyedvectors.Vocab at 0x1d0538fa9c8>,
#  'of': <gensim.models.keyedvectors.Vocab at 0x1d0538faa08>,
#  'caramel': <gensim.models.keyedvectors.Vocab at 0x1d0538faa48>,
#  'greet': <gensim.models.keyedvectors.Vocab at 0x1d0538faa88>,
#  'the': <gensim.models.keyedvectors.Vocab at 0x1d0538faac8>,
#  'palate': <gensim.models.keyedvectors.Vocab at 0x1d0538fab08>,
#  'framed': <gensim.models.keyedvectors.Vocab at 0x1d0538fab48>,
#  'by': <gensim.models.keyedvectors.Vocab at 0x1d0538fab88>,
#  'elegant': <gensim.models.keyedvectors.Vocab at 0x1d0538fabc8>,
#  'fine': <gensim.models.keyedvectors.Vocab at 0x1d0538fac08>,
#  'tannins': <gensim.models.keyedvectors.Vocab at 0x1d0538fac48>,
#  'subtle': <gensim.models.keyedvectors.Vocab at 0x1d0538fac88>,
#  'minty': <gensim.models.keyedvectors.Vocab at 0x1d0538facc8>,
#  'tone': <gensim.models.keyedvectors.Vocab at 0x1d0538fad08>,
#  'background': <gensim.models.keyedvectors.Vocab at 0x1d0538fad48>,
#  'Balanced': <gensim.models.keyedvectors.Vocab at 0x1d0538fad88>,
#  'rewarding': <gensim.models.keyedvectors.Vocab at 0x1d0538fadc8>,
#  'start': <gensim.models.keyedvectors.Vocab at 0x1d0538fae08>,
#  'to': <gensim.models.keyedvectors.Vocab at 0x1d0538fae48>,
#  'finish': <gensim.models.keyedvectors.Vocab at 0x1d0538fae88>,
#  'it': <gensim.models.keyedvectors.Vocab at 0x1d0538faec8>,
#  'has': <gensim.models.keyedvectors.Vocab at 0x1d0538faf08>,
#  'ahead': <gensim.models.keyedvectors.Vocab at 0x1d0538faf48>,
#  'develop': <gensim.models.keyedvectors.Vocab at 0x1d0538faf88>,
#  'further': <gensim.models.keyedvectors.Vocab at 0x1d0538fafc8>,
#  'nuance': <gensim.models.keyedvectors.Vocab at 0x1d053a5c048>,
#  'Enjoy': <gensim.models.keyedvectors.Vocab at 0x1d053a5c088>,
#  'Ripe': <gensim.models.keyedvectors.Vocab at 0x1d053a5c0c8>,
#  'aromas': <gensim.models.keyedvectors.Vocab at 0x1d053a5c108>,
#  'fig': <gensim.models.keyedvectors.Vocab at 0x1d053a5c148>,
#  'blackberry': <gensim.models.keyedvectors.Vocab at 0x1d053a5c188>,
#  'cassis': <gensim.models.keyedvectors.Vocab at 0x1d053a5c1c8>,
#  'are': <gensim.models.keyedvectors.Vocab at 0x1d053a5c208>,
#  'softened': <gensim.models.keyedvectors.Vocab at 0x1d053a5c248>,
#  'sweetened': <gensim.models.keyedvectors.Vocab at 0x1d053a5c288>,
#  'oaky': <gensim.models.keyedvectors.Vocab at 0x1d053a5c2c8>,
#  'chocolate': <gensim.models.keyedvectors.Vocab at 0x1d053a5c308>,
#  'vanilla': <gensim.models.keyedvectors.Vocab at 0x1d053a5c348>,
#  'is': <gensim.models.keyedvectors.Vocab at 0x1d053a5c388>,
#  'full': <gensim.models.keyedvectors.Vocab at 0x1d053a5c3c8>,
#  'layered': <gensim.models.keyedvectors.Vocab at 0x1d053a5c408>,
#  'intense': <gensim.models.keyedvectors.Vocab at 0x1d053a5c448>,
#  'cushioned': <gensim.models.keyedvectors.Vocab at 0x1d053a5c488>,
#  'on': <gensim.models.keyedvectors.Vocab at 0x1d053a5c4c8>,
#  'with': <gensim.models.keyedvectors.Vocab at 0x1d053a5c508>,
#  'rich': <gensim.models.keyedvectors.Vocab at 0x1d053a5c548>,
#  'flavors': <gensim.models.keyedvectors.Vocab at 0x1d053a5c588>,
#  'chocolaty': <gensim.models.keyedvectors.Vocab at 0x1d053a5c5c8>,
#  'black': <gensim.models.keyedvectors.Vocab at 0x1d053a5c608>,
#  'fruits': <gensim.models.keyedvectors.Vocab at 0x1d053a5c648>,
#  'baking': <gensim.models.keyedvectors.Vocab at 0x1d053a5c688>,
#  'spices': <gensim.models.keyedvectors.Vocab at 0x1d053a5c6c8>,
#  'A': <gensim.models.keyedvectors.Vocab at 0x1d053a5c708>,
#  'toasty': <gensim.models.keyedvectors.Vocab at 0x1d053a5c748>,
#  'heady': <gensim.models.keyedvectors.Vocab at 0x1d053a5c788>,
#  'but': <gensim.models.keyedvectors.Vocab at 0x1d053a5c7c8>,
#  'ideally': <gensim.models.keyedvectors.Vocab at 0x1d053a5c808>,
#  'balanced': <gensim.models.keyedvectors.Vocab at 0x1d053a5c848>,
#  'Drink': <gensim.models.keyedvectors.Vocab at 0x1d053a5c888>,
#  'through': <gensim.models.keyedvectors.Vocab at 0x1d053a5c8c8>,
#  'honors': <gensim.models.keyedvectors.Vocab at 0x1d053a5c908>,
#  'memory': <gensim.models.keyedvectors.Vocab at 0x1d053a5c948>,
#  'once': <gensim.models.keyedvectors.Vocab at 0x1d053a5c988>,
#  'made': <gensim.models.keyedvectors.Vocab at 0x1d053a5c9c8>,
#  'his': <gensim.models.keyedvectors.Vocab at 0x1d053a5ca08>,
#  'mother': <gensim.models.keyedvectors.Vocab at 0x1d053a5ca48>,
#  'this': <gensim.models.keyedvectors.Vocab at 0x1d053a5ca88>,
#  'tremendously': <gensim.models.keyedvectors.Vocab at 0x1d053a5cac8>,
#  'delicious': <gensim.models.keyedvectors.Vocab at 0x1d053a5cb08>,
#  'complex': <gensim.models.keyedvectors.Vocab at 0x1d053a5cb48>,
#  'botrytised': <gensim.models.keyedvectors.Vocab at 0x1d053a5cb88>,
#  'white': <gensim.models.keyedvectors.Vocab at 0x1d053a5cbc8>,
#  'Dark': <gensim.models.keyedvectors.Vocab at 0x1d053a5cc08>,
#  'gold': <gensim.models.keyedvectors.Vocab at 0x1d053a5cc48>,
#  'color': <gensim.models.keyedvectors.Vocab at 0x1d053a5cc88>,
#  'layers': <gensim.models.keyedvectors.Vocab at 0x1d053a5ccc8>,
#  'toasted': <gensim.models.keyedvectors.Vocab at 0x1d053a5cd08>,
#  'hazelnut': <gensim.models.keyedvectors.Vocab at 0x1d053a5cd48>,
#  'pear': <gensim.models.keyedvectors.Vocab at 0x1d053a5cd88>,
#  'compote': <gensim.models.keyedvectors.Vocab at 0x1d053a5cdc8>,
#  'orange': <gensim.models.keyedvectors.Vocab at 0x1d053a5ce08>,
#  'peel': <gensim.models.keyedvectors.Vocab at 0x1d053a5ce48>,
#  'succulence': <gensim.models.keyedvectors.Vocab at 0x1d053a5ce88>,
#  'its': <gensim.models.keyedvectors.Vocab at 0x1d053a5cec8>,
#  'g': <gensim.models.keyedvectors.Vocab at 0x1d053a5cf08>,
#  'L': <gensim.models.keyedvectors.Vocab at 0x1d053a5cf48>,
#  'residual': <gensim.models.keyedvectors.Vocab at 0x1d053a5cf88>,
#  'sugar': <gensim.models.keyedvectors.Vocab at 0x1d053a5cfc8>,
#  'spent': <gensim.models.keyedvectors.Vocab at 0x1d053a5f048>,
#  'months': <gensim.models.keyedvectors.Vocab at 0x1d053a5f088>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x1d053a5f0c8>,
#  'French': <gensim.models.keyedvectors.Vocab at 0x1d053a5f108>,
#  'incorporates': <gensim.models.keyedvectors.Vocab at 0x1d053a5f148>,
#  'Ponzi': <gensim.models.keyedvectors.Vocab at 0x1d053a5f188>,
#  's': <gensim.models.keyedvectors.Vocab at 0x1d053a5f1c8>,
#  'vineyards': <gensim.models.keyedvectors.Vocab at 0x1d053a5f208>,
#  'among': <gensim.models.keyedvectors.Vocab at 0x1d053a5f248>,
#  'others': <gensim.models.keyedvectors.Vocab at 0x1d053a5f288>,
#  'Aromatic': <gensim.models.keyedvectors.Vocab at 0x1d053a5f2c8>,
#  'dense': <gensim.models.keyedvectors.Vocab at 0x1d053a5f308>,
#  'deftly': <gensim.models.keyedvectors.Vocab at 0x1d053a5f348>,
#  'blends': <gensim.models.keyedvectors.Vocab at 0x1d053a5f388>,
#  'toast': <gensim.models.keyedvectors.Vocab at 0x1d053a5f3c8>,
#  'cigar': <gensim.models.keyedvectors.Vocab at 0x1d053a5f408>,
#  'box': <gensim.models.keyedvectors.Vocab at 0x1d053a5f448>,
#  'coffee': <gensim.models.keyedvectors.Vocab at 0x1d053a5f488>,
#  'graphite': <gensim.models.keyedvectors.Vocab at 0x1d053a5f4c8>,
#  'Tannins': <gensim.models.keyedvectors.Vocab at 0x1d053a5f508>,
#  'polished': <gensim.models.keyedvectors.Vocab at 0x1d053a5f548>,
#  'sheen': <gensim.models.keyedvectors.Vocab at 0x1d053a5f588>,
#  'frame': <gensim.models.keyedvectors.Vocab at 0x1d053a5f5c8>,
#  'loaded': <gensim.models.keyedvectors.Vocab at 0x1d053a5f608>,
#  'dark': <gensim.models.keyedvectors.Vocab at 0x1d053a5f648>,
#  'espresso': <gensim.models.keyedvectors.Vocab at 0x1d053a5f688>,
#  'now': <gensim.models.keyedvectors.Vocab at 0x1d053a5f6c8>,
#  'top': <gensim.models.keyedvectors.Vocab at 0x1d053a5f708>,
#  'La': <gensim.models.keyedvectors.Vocab at 0x1d053a5f748>,
#  'B': <gensim.models.keyedvectors.Vocab at 0x1d053a5f788>,
#  'named': <gensim.models.keyedvectors.Vocab at 0x1d053a5f7c8>,
#  'after': <gensim.models.keyedvectors.Vocab at 0x1d053a5f808>,
#  'highest': <gensim.models.keyedvectors.Vocab at 0x1d053a5f848>,
#  'point': <gensim.models.keyedvectors.Vocab at 0x1d053a5f888>,
#  'vineyard': <gensim.models.keyedvectors.Vocab at 0x1d053a5f8c8>,
#  'at': <gensim.models.keyedvectors.Vocab at 0x1d053a5f908>,
#  'feet': <gensim.models.keyedvectors.Vocab at 0x1d053a5f948>,
#  'It': <gensim.models.keyedvectors.Vocab at 0x1d053a5f988>,
#  'structure': <gensim.models.keyedvectors.Vocab at 0x1d053a5f9c8>,
#  'density': <gensim.models.keyedvectors.Vocab at 0x1d053a5fa08>,
#  'considerable': <gensim.models.keyedvectors.Vocab at 0x1d053a5fa48>,
#  'acidity': <gensim.models.keyedvectors.Vocab at 0x1d053a5fa88>,
#  'that': <gensim.models.keyedvectors.Vocab at 0x1d053a5fac8>,
#  'still': <gensim.models.keyedvectors.Vocab at 0x1d053a5fb08>,
#  'calming': <gensim.models.keyedvectors.Vocab at 0x1d053a5fb48>,
#  'down': <gensim.models.keyedvectors.Vocab at 0x1d053a5fb88>,
#  'With': <gensim.models.keyedvectors.Vocab at 0x1d053a5fbc8>,
#  'wood': <gensim.models.keyedvectors.Vocab at 0x1d053a5fc08>,
#  'developing': <gensim.models.keyedvectors.Vocab at 0x1d053a5fc48>,
#  'an': <gensim.models.keyedvectors.Vocab at 0x1d053a5fc88>,
#  'extra': <gensim.models.keyedvectors.Vocab at 0x1d053a5fcc8>,
#  'richness': <gensim.models.keyedvectors.Vocab at 0x1d053a5fd08>,
#  'concentration': <gensim.models.keyedvectors.Vocab at 0x1d053a5fd48>,
#  'Produced': <gensim.models.keyedvectors.Vocab at 0x1d053a5fd88>,
#  'family': <gensim.models.keyedvectors.Vocab at 0x1d053a5fdc8>,
#  'formerly': <gensim.models.keyedvectors.Vocab at 0x1d053a5fe08>,
#  'Ch': <gensim.models.keyedvectors.Vocab at 0x1d053a5fe48>,
#  'teau': <gensim.models.keyedvectors.Vocab at 0x1d053a5fe88>,
#  'Giscours': <gensim.models.keyedvectors.Vocab at 0x1d053a5fec8>,
#  'Margaux': <gensim.models.keyedvectors.Vocab at 0x1d053a5ff08>,
#  'for': <gensim.models.keyedvectors.Vocab at 0x1d053a5ff48>,
#  'aging': <gensim.models.keyedvectors.Vocab at 0x1d053a5ff88>,
#  'Deep': <gensim.models.keyedvectors.Vocab at 0x1d053a5ffc8>,
#  'pure': <gensim.models.keyedvectors.Vocab at 0x1d053a62048>,
#  'opening': <gensim.models.keyedvectors.Vocab at 0x1d053a62088>,
#  'bell': <gensim.models.keyedvectors.Vocab at 0x1d053a620c8>,
#  'Toro': <gensim.models.keyedvectors.Vocab at 0x1d053a62108>,
#  'winner': <gensim.models.keyedvectors.Vocab at 0x1d053a62148>,
#  'Aromas': <gensim.models.keyedvectors.Vocab at 0x1d053a62188>,
#  'ripe': <gensim.models.keyedvectors.Vocab at 0x1d053a621c8>,
#  'cool': <gensim.models.keyedvectors.Vocab at 0x1d053a62208>,
#  'moderately': <gensim.models.keyedvectors.Vocab at 0x1d053a62248>,
#  'oaked': <gensim.models.keyedvectors.Vocab at 0x1d053a62288>,
#  'feels': <gensim.models.keyedvectors.Vocab at 0x1d053a622c8>,
#  'massive': <gensim.models.keyedvectors.Vocab at 0x1d053a62308>,
#  'Flavors': <gensim.models.keyedvectors.Vocab at 0x1d053a62348>,
#  'mocha': <gensim.models.keyedvectors.Vocab at 0x1d053a62388>,
#  'spicy': <gensim.models.keyedvectors.Vocab at 0x1d053a623c8>,
#  'smooth': <gensim.models.keyedvectors.Vocab at 0x1d053a62408>,
#  'exemplary': <gensim.models.keyedvectors.Vocab at 0x1d053a62448>,
#  'Slightly': <gensim.models.keyedvectors.Vocab at 0x1d053a62488>,
#  'gritty': <gensim.models.keyedvectors.Vocab at 0x1d053a624c8>,
#  'include': <gensim.models.keyedvectors.Vocab at 0x1d053a62508>,
#  'sweet': <gensim.models.keyedvectors.Vocab at 0x1d053a62548>,
#  'note': <gensim.models.keyedvectors.Vocab at 0x1d053a62588>,
#  'pastry': <gensim.models.keyedvectors.Vocab at 0x1d053a625c8>,
#  'along': <gensim.models.keyedvectors.Vocab at 0x1d053a62608>,
#  'prune': <gensim.models.keyedvectors.Vocab at 0x1d053a62648>,
#  'wall': <gensim.models.keyedvectors.Vocab at 0x1d053a62688>,
#  'saturation': <gensim.models.keyedvectors.Vocab at 0x1d053a626c8>,
#  'ensures': <gensim.models.keyedvectors.Vocab at 0x1d053a62708>,
#  'all': <gensim.models.keyedvectors.Vocab at 0x1d053a62748>,
#  'corners': <gensim.models.keyedvectors.Vocab at 0x1d053a62788>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x1d053a627c8>,
#  'mouth': <gensim.models.keyedvectors.Vocab at 0x1d053a62808>,
#  'covered': <gensim.models.keyedvectors.Vocab at 0x1d053a62848>,
#  'highly': <gensim.models.keyedvectors.Vocab at 0x1d053a62888>,
#  'impressive': <gensim.models.keyedvectors.Vocab at 0x1d053a628c8>,
#  'expressive': <gensim.models.keyedvectors.Vocab at 0x1d053a62908>,
#  'while': <gensim.models.keyedvectors.Vocab at 0x1d053a62948>,
#  'settles': <gensim.models.keyedvectors.Vocab at 0x1d053a62988>,
#  'nicely': <gensim.models.keyedvectors.Vocab at 0x1d053a629c8>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x1d053a62a08>,
#  'Lush': <gensim.models.keyedvectors.Vocab at 0x1d053a62a48>,
#  'cedary': <gensim.models.keyedvectors.Vocab at 0x1d053a62a88>,
#  'luxe': <gensim.models.keyedvectors.Vocab at 0x1d053a62ac8>,
#  'offer': <gensim.models.keyedvectors.Vocab at 0x1d053a62b08>,
#  'notes': <gensim.models.keyedvectors.Vocab at 0x1d053a62b48>,
#  'marzipan': <gensim.models.keyedvectors.Vocab at 0x1d053a62b88>,
#  'bruiser': <gensim.models.keyedvectors.Vocab at 0x1d053a62bc8>,
#  'tannic': <gensim.models.keyedvectors.Vocab at 0x1d053a62c08>,
#  'lush': <gensim.models.keyedvectors.Vocab at 0x1d053a62c48>,
#  'friendly': <gensim.models.keyedvectors.Vocab at 0x1d053a62c88>,
#  'Chocolate': <gensim.models.keyedvectors.Vocab at 0x1d053a62cc8>,
#  'key': <gensim.models.keyedvectors.Vocab at 0x1d053a62d08>,
#  'flavor': <gensim.models.keyedvectors.Vocab at 0x1d053a62d48>,
#  'baked': <gensim.models.keyedvectors.Vocab at 0x1d053a62d88>,
#  'berry': <gensim.models.keyedvectors.Vocab at 0x1d053a62dc8>,
#  'hardly': <gensim.models.keyedvectors.Vocab at 0x1d053a62e08>,
#  'On': <gensim.models.keyedvectors.Vocab at 0x1d053a62e48>,
#  'deep': <gensim.models.keyedvectors.Vocab at 0x1d053a62e88>,
#  'as': <gensim.models.keyedvectors.Vocab at 0x1d0538f4a08>,
#  'sea': <gensim.models.keyedvectors.Vocab at 0x1d0538f4508>,
#  'saturated': <gensim.models.keyedvectors.Vocab at 0x1d0538f48c8>,
#  'colored': <gensim.models.keyedvectors.Vocab at 0x1d0538f4bc8>,
#  're': <gensim.models.keyedvectors.Vocab at 0x1d0538f44c8>,
#  'bottled': <gensim.models.keyedvectors.Vocab at 0x1d0538f4288>,
#  'You': <gensim.models.keyedvectors.Vocab at 0x1d0538f4188>,
#  'll': <gensim.models.keyedvectors.Vocab at 0x1d0538f4248>,
#  'find': <gensim.models.keyedvectors.Vocab at 0x1d0538f4208>,
#  'striking': <gensim.models.keyedvectors.Vocab at 0x1d0538f41c8>,
#  'minerality': <gensim.models.keyedvectors.Vocab at 0x1d033db2b88>,
#  'underscoring': <gensim.models.keyedvectors.Vocab at 0x1d033dde108>,
#  'chunky': <gensim.models.keyedvectors.Vocab at 0x1d0308a1dc8>,
#  'Accents': <gensim.models.keyedvectors.Vocab at 0x1d0538f2cc8>,
#  'citrus': <gensim.models.keyedvectors.Vocab at 0x1d0538f2fc8>,
#  'exceptional': <gensim.models.keyedvectors.Vocab at 0x1d0538f2788>,
#  'midpalate': <gensim.models.keyedvectors.Vocab at 0x1d0538f2808>,
#  'cellar': <gensim.models.keyedvectors.Vocab at 0x1d0538f2d08>,
#  'though': <gensim.models.keyedvectors.Vocab at 0x1d0538f2088>,
#  'already': <gensim.models.keyedvectors.Vocab at 0x1d0538f24c8>,
#  'quite': <gensim.models.keyedvectors.Vocab at 0x1d0538f27c8>,
#  'enjoyable': <gensim.models.keyedvectors.Vocab at 0x1d0538f2748>,
#  'The': <gensim.models.keyedvectors.Vocab at 0x1d0538f2688>,
#  'producer': <gensim.models.keyedvectors.Vocab at 0x1d0538f2d88>,
#  'sources': <gensim.models.keyedvectors.Vocab at 0x1d0538f2e88>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x1d0538f2448>,
#  'blocks': <gensim.models.keyedvectors.Vocab at 0x1d0538f2488>,
#  'high': <gensim.models.keyedvectors.Vocab at 0x1d0538f2608>,
#  'elevation': <gensim.models.keyedvectors.Vocab at 0x1d0538eee88>,
#  'which': <gensim.models.keyedvectors.Vocab at 0x1d0538ee508>,
#  'contributes': <gensim.models.keyedvectors.Vocab at 0x1d0538eea48>,
#  'bright': <gensim.models.keyedvectors.Vocab at 0x1d0538eebc8>,
#  'Crunchy': <gensim.models.keyedvectors.Vocab at 0x1d0538eed08>,
#  'cranberry': <gensim.models.keyedvectors.Vocab at 0x1d0538eeb08>,
#  'pomegranate': <gensim.models.keyedvectors.Vocab at 0x1d0538ee888>,
#  'surround': <gensim.models.keyedvectors.Vocab at 0x1d0538eea08>,
#  'silky': <gensim.models.keyedvectors.Vocab at 0x1d0538ee9c8>,
#  'succulent': <gensim.models.keyedvectors.Vocab at 0x1d0538ee988>,
#  'texture': <gensim.models.keyedvectors.Vocab at 0x1d0538ee948>,
#  'present': <gensim.models.keyedvectors.Vocab at 0x1d0538ee8c8>,
#  'fleshy': <gensim.models.keyedvectors.Vocab at 0x1d0538ee848>,
#  'That': <gensim.models.keyedvectors.Vocab at 0x1d0538ee708>,
#  'delicately': <gensim.models.keyedvectors.Vocab at 0x1d0538ee908>,
#  'length': <gensim.models.keyedvectors.Vocab at 0x1d0538ee5c8>,
#  'Elegance': <gensim.models.keyedvectors.Vocab at 0x1d0538ee308>,
#  'complexity': <gensim.models.keyedvectors.Vocab at 0x1d0538ee548>,
#  'come': <gensim.models.keyedvectors.Vocab at 0x1d0538ee648>,
#  'together': <gensim.models.keyedvectors.Vocab at 0x1d0538eecc8>,
#  'drop': <gensim.models.keyedvectors.Vocab at 0x1d0538ee448>,
#  'dead': <gensim.models.keyedvectors.Vocab at 0x1d0538ee408>,
#  'gorgeous': <gensim.models.keyedvectors.Vocab at 0x1d030ad14c8>,
#  'ranks': <gensim.models.keyedvectors.Vocab at 0x1d030ad1a08>,
#  'Italy': <gensim.models.keyedvectors.Vocab at 0x1d030ad1808>,
#  'greatest': <gensim.models.keyedvectors.Vocab at 0x1d030ad1308>,
#  'whites': <gensim.models.keyedvectors.Vocab at 0x1d030ad17c8>,
#  'opens': <gensim.models.keyedvectors.Vocab at 0x1d030ad1d48>,
#  'sublime': <gensim.models.keyedvectors.Vocab at 0x1d030ad1248>,
#  'yellow': <gensim.models.keyedvectors.Vocab at 0x1d030ad1508>,
#  'spring': <gensim.models.keyedvectors.Vocab at 0x1d0538eff88>,
#  'flower': <gensim.models.keyedvectors.Vocab at 0x1d0538efb88>,
#  'aromatic': <gensim.models.keyedvectors.Vocab at 0x1d0538efd48>,
#  'herb': <gensim.models.keyedvectors.Vocab at 0x1d0538efd08>,
#  'orchard': <gensim.models.keyedvectors.Vocab at 0x1d0538efcc8>,
#  'scents': <gensim.models.keyedvectors.Vocab at 0x1d0538efc88>,
#  'creamy': <gensim.models.keyedvectors.Vocab at 0x1d0538efc48>,
#  'seamlessly': <gensim.models.keyedvectors.Vocab at 0x1d0538efc08>,
#  'combines': <gensim.models.keyedvectors.Vocab at 0x1d0538efbc8>,
#  'juicy': <gensim.models.keyedvectors.Vocab at 0x1d0538efb08>,
#  'peach': <gensim.models.keyedvectors.Vocab at 0x1d0538efac8>,
#  'almond': <gensim.models.keyedvectors.Vocab at 0x1d0538efa88>,
#  'savory': <gensim.models.keyedvectors.Vocab at 0x1d0538efa48>,
#  'mineral': <gensim.models.keyedvectors.Vocab at 0x1d0538efa08>,
#  'grace': <gensim.models.keyedvectors.Vocab at 0x1d053a62ec8>,
#  'lingering': <gensim.models.keyedvectors.Vocab at 0x1d053a62f08>,
#  'From': <gensim.models.keyedvectors.Vocab at 0x1d053a62f48>,
#  'year': <gensim.models.keyedvectors.Vocab at 0x1d053a62f88>,
#  'old': <gensim.models.keyedvectors.Vocab at 0x1d053a62fc8>,
#  'vines': <gensim.models.keyedvectors.Vocab at 0x1d053a66048>,
#  'supple': <gensim.models.keyedvectors.Vocab at 0x1d053a66088>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x1d053a660c8>,
#  'effort': <gensim.models.keyedvectors.Vocab at 0x1d053a66108>,
#  'breakfast': <gensim.models.keyedvectors.Vocab at 0x1d053a66148>,
#  'tea': <gensim.models.keyedvectors.Vocab at 0x1d053a66188>,
#  'Superbly': <gensim.models.keyedvectors.Vocab at 0x1d053a661c8>,
#  'integrated': <gensim.models.keyedvectors.Vocab at 0x1d053a66208>,
#  'even': <gensim.models.keyedvectors.Vocab at 0x1d053a66248>,
#  'early': <gensim.models.keyedvectors.Vocab at 0x1d053a66288>,
#  'stage': <gensim.models.keyedvectors.Vocab at 0x1d053a662c8>,
#  'seems': <gensim.models.keyedvectors.Vocab at 0x1d053a66308>,
#  'destined': <gensim.models.keyedvectors.Vocab at 0x1d053a66348>,
#  'life': <gensim.models.keyedvectors.Vocab at 0x1d053a66388>,
#  'standout': <gensim.models.keyedvectors.Vocab at 0x1d053a663c8>,
#  'terrific': <gensim.models.keyedvectors.Vocab at 0x1d053a66408>,
#  'lineup': <gensim.models.keyedvectors.Vocab at 0x1d053a66448>,
#  'releases': <gensim.models.keyedvectors.Vocab at 0x1d053a66488>,
#  'Green': <gensim.models.keyedvectors.Vocab at 0x1d053a664c8>,
#  'burst': <gensim.models.keyedvectors.Vocab at 0x1d053a66508>,
#  'cola': <gensim.models.keyedvectors.Vocab at 0x1d053a66548>,
#  'tobacco': <gensim.models.keyedvectors.Vocab at 0x1d053a66588>,
#  'accents': <gensim.models.keyedvectors.Vocab at 0x1d053a665c8>,
#  'continues': <gensim.models.keyedvectors.Vocab at 0x1d053a66608>,
#  'detailed': <gensim.models.keyedvectors.Vocab at 0x1d053a66648>,
#  'oranges': <gensim.models.keyedvectors.Vocab at 0x1d053a66688>,
#  'milk': <gensim.models.keyedvectors.Vocab at 0x1d053a666c8>,
#  'threaded': <gensim.models.keyedvectors.Vocab at 0x1d053a66708>,
#  'peak': <gensim.models.keyedvectors.Vocab at 0x1d053a66748>,
#  'condition': <gensim.models.keyedvectors.Vocab at 0x1d053a66788>,
#  'secondary': <gensim.models.keyedvectors.Vocab at 0x1d053a667c8>,
#  'dominate': <gensim.models.keyedvectors.Vocab at 0x1d053a66808>,
#  'leather': <gensim.models.keyedvectors.Vocab at 0x1d053a66848>,
#  'textured': <gensim.models.keyedvectors.Vocab at 0x1d053a66888>,
#  'there': <gensim.models.keyedvectors.Vocab at 0x1d053a668c8>,
#  'dried': <gensim.models.keyedvectors.Vocab at 0x1d053a66908>,
#  'berries': <gensim.models.keyedvectors.Vocab at 0x1d053a66948>,
#  'hints': <gensim.models.keyedvectors.Vocab at 0x1d053a66988>,
#  'plum': <gensim.models.keyedvectors.Vocab at 0x1d053a669c8>,
#  'skins': <gensim.models.keyedvectors.Vocab at 0x1d053a66a08>,
#  'major': <gensim.models.keyedvectors.Vocab at 0x1d053a66a48>,
#  'right': <gensim.models.keyedvectors.Vocab at 0x1d053a66a88>,
#  'drinking': <gensim.models.keyedvectors.Vocab at 0x1d053a66ac8>,
#  'both': <gensim.models.keyedvectors.Vocab at 0x1d053a66b08>,
#  'mature': <gensim.models.keyedvectors.Vocab at 0x1d053a66b48>,
#  'balance': <gensim.models.keyedvectors.Vocab at 0x1d053a66b88>,
#  'sophisticated': <gensim.models.keyedvectors.Vocab at 0x1d053a66bc8>,
#  'mix': <gensim.models.keyedvectors.Vocab at 0x1d053a66c08>,
#  'acid': <gensim.models.keyedvectors.Vocab at 0x1d053a66c48>,
#  'tart': <gensim.models.keyedvectors.Vocab at 0x1d053a66c88>,
#  'seductive': <gensim.models.keyedvectors.Vocab at 0x1d053a66cc8>,
#  'pleases': <gensim.models.keyedvectors.Vocab at 0x1d053a66d08>,
#  'Supple': <gensim.models.keyedvectors.Vocab at 0x1d053a66d48>,
#  'got': <gensim.models.keyedvectors.Vocab at 0x1d053a66d88>,
#  'strawberry': <gensim.models.keyedvectors.Vocab at 0x1d053a66dc8>,
#  'blueberry': <gensim.models.keyedvectors.Vocab at 0x1d053a66e08>,
#  'touch': <gensim.models.keyedvectors.Vocab at 0x1d053a66e48>,
#  'underlying': <gensim.models.keyedvectors.Vocab at 0x1d053a66e88>,
#  'streak': <gensim.models.keyedvectors.Vocab at 0x1d053a66ec8>,
#  'All': <gensim.models.keyedvectors.Vocab at 0x1d053a66f08>,
#  'these': <gensim.models.keyedvectors.Vocab at 0x1d053a66f48>,
#  'elements': <gensim.models.keyedvectors.Vocab at 0x1d053a66f88>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x1d053a66fc8>,
#  'proportion': <gensim.models.keyedvectors.Vocab at 0x1d053a69048>,
#  'appealing': <gensim.models.keyedvectors.Vocab at 0x1d053a69088>,
#  'give': <gensim.models.keyedvectors.Vocab at 0x1d053a690c8>,
#  'another': <gensim.models.keyedvectors.Vocab at 0x1d053a69108>,
#  'decade': <gensim.models.keyedvectors.Vocab at 0x1d053a69148>,
#  'enjoyment': <gensim.models.keyedvectors.Vocab at 0x1d053a69188>,
#  'First': <gensim.models.keyedvectors.Vocab at 0x1d053a691c8>,
#  'luscious': <gensim.models.keyedvectors.Vocab at 0x1d053a69208>,
#  'Chardonnay': <gensim.models.keyedvectors.Vocab at 0x1d053a69248>,
#  'about': <gensim.models.keyedvectors.Vocab at 0x1d053a69288>,
#  'core': <gensim.models.keyedvectors.Vocab at 0x1d053a692c8>,
#  'butterscotch': <gensim.models.keyedvectors.Vocab at 0x1d053a69308>,
#  'seemingly': <gensim.models.keyedvectors.Vocab at 0x1d053a69348>,
#  'endless': <gensim.models.keyedvectors.Vocab at 0x1d053a69388>,
#  'biodynamic': <gensim.models.keyedvectors.Vocab at 0x1d053a693c8>,
#  'farming': <gensim.models.keyedvectors.Vocab at 0x1d053a69408>,
#  'can': <gensim.models.keyedvectors.Vocab at 0x1d053a69448>,
#  'bring': <gensim.models.keyedvectors.Vocab at 0x1d053a69488>,
#  'spends': <gensim.models.keyedvectors.Vocab at 0x1d053a694c8>,
#  'lees': <gensim.models.keyedvectors.Vocab at 0x1d053a69508>,
#  'prior': <gensim.models.keyedvectors.Vocab at 0x1d053a69548>,
#  'bottling': <gensim.models.keyedvectors.Vocab at 0x1d053a69588>,
#  'blockbuster': <gensim.models.keyedvectors.Vocab at 0x1d053a695c8>,
#  'powerhouse': <gensim.models.keyedvectors.Vocab at 0x1d053a69608>,
#  'suggests': <gensim.models.keyedvectors.Vocab at 0x1d053a69648>,
#  'pie': <gensim.models.keyedvectors.Vocab at 0x1d053a69688>,
#  'glass': <gensim.models.keyedvectors.Vocab at 0x1d053a696c8>,
#  'seductively': <gensim.models.keyedvectors.Vocab at 0x1d053a69708>,
#  'offering': <gensim.models.keyedvectors.Vocab at 0x1d053a69748>,
#  'cedar': <gensim.models.keyedvectors.Vocab at 0x1d053a69788>,
#  'peppercorn': <gensim.models.keyedvectors.Vocab at 0x1d053a697c8>,
#  'peppery': <gensim.models.keyedvectors.Vocab at 0x1d053a69808>,
#  'seasonings': <gensim.models.keyedvectors.Vocab at 0x1d053a69848>,
#  'amidst': <gensim.models.keyedvectors.Vocab at 0x1d053a69888>,
#  'finishes': <gensim.models.keyedvectors.Vocab at 0x1d053a698c8>,
#  'finesse': <gensim.models.keyedvectors.Vocab at 0x1d053a69908>,
#  'spice': <gensim.models.keyedvectors.Vocab at 0x1d053a69948>,
#  'Nicely': <gensim.models.keyedvectors.Vocab at 0x1d053a69988>,
#  'licorice': <gensim.models.keyedvectors.Vocab at 0x1d053a699c8>,
#  'charred': <gensim.models.keyedvectors.Vocab at 0x1d053a69a08>,
#  'sultry': <gensim.models.keyedvectors.Vocab at 0x1d053a69a48>,
#  'outstanding': <gensim.models.keyedvectors.Vocab at 0x1d053a69a88>,
#  'excellent': <gensim.models.keyedvectors.Vocab at 0x1d053a69ac8>,
#  'Forward': <gensim.models.keyedvectors.Vocab at 0x1d053a69b08>,
#  'barrel': <gensim.models.keyedvectors.Vocab at 0x1d053a69b48>,
#  'adorn': <gensim.models.keyedvectors.Vocab at 0x1d053a69b88>,
#  'raspberry': <gensim.models.keyedvectors.Vocab at 0x1d053a69bc8>,
#  'runs': <gensim.models.keyedvectors.Vocab at 0x1d053a69c08>,
#  'tastes': <gensim.models.keyedvectors.Vocab at 0x1d053a69c48>,
#  'vaguely': <gensim.models.keyedvectors.Vocab at 0x1d053a69c88>,
#  'velvety': <gensim.models.keyedvectors.Vocab at 0x1d053a69cc8>,
#  'notch': <gensim.models.keyedvectors.Vocab at 0x1d053a69d08>,
#  'Tempranillo': <gensim.models.keyedvectors.Vocab at 0x1d053a69d48>,
#  'Coming': <gensim.models.keyedvectors.Vocab at 0x1d053a69d88>,
#  'seven': <gensim.models.keyedvectors.Vocab at 0x1d053a69dc8>,
#  'acre': <gensim.models.keyedvectors.Vocab at 0x1d053a69e08>,
#  'property': <gensim.models.keyedvectors.Vocab at 0x1d053a69e48>,
#  'magnificent': <gensim.models.keyedvectors.Vocab at 0x1d053a69e88>,
#  'Powered': <gensim.models.keyedvectors.Vocab at 0x1d053a69ec8>,
#  'darkly': <gensim.models.keyedvectors.Vocab at 0x1d053a69f08>,
#  'great': <gensim.models.keyedvectors.Vocab at 0x1d053a69f48>,
#  'As': <gensim.models.keyedvectors.Vocab at 0x1d053a69f88>,
#  'sign': <gensim.models.keyedvectors.Vocab at 0x1d053a69fc8>,
#  'pedigree': <gensim.models.keyedvectors.Vocab at 0x1d053a6e048>,
#  'also': <gensim.models.keyedvectors.Vocab at 0x1d053a6e088>,
#  'elegance': <gensim.models.keyedvectors.Vocab at 0x1d053a6e0c8>,
#  'here': <gensim.models.keyedvectors.Vocab at 0x1d053a6e108>,
#  'restraint': <gensim.models.keyedvectors.Vocab at 0x1d053a6e148>,
#  'makes': <gensim.models.keyedvectors.Vocab at 0x1d053a6e188>,
#  'term': <gensim.models.keyedvectors.Vocab at 0x1d053a6e1c8>,
#  'fresh': <gensim.models.keyedvectors.Vocab at 0x1d053a6e208>,
#  'lively': <gensim.models.keyedvectors.Vocab at 0x1d053a6e248>,
#  'medium': <gensim.models.keyedvectors.Vocab at 0x1d053a6e288>,
#  'bodied': <gensim.models.keyedvectors.Vocab at 0x1d053a6e2c8>,
#  'beautifully': <gensim.models.keyedvectors.Vocab at 0x1d053a6e308>,
#  'crafted': <gensim.models.keyedvectors.Vocab at 0x1d053a6e348>,
#  'blossom': <gensim.models.keyedvectors.Vocab at 0x1d053a6e388>,
#  'tangy': <gensim.models.keyedvectors.Vocab at 0x1d053a6e3c8>,
#  'Layered': <gensim.models.keyedvectors.Vocab at 0x1d053a6e408>,
#  'offers': <gensim.models.keyedvectors.Vocab at 0x1d053a6e448>,
#  'crisp': <gensim.models.keyedvectors.Vocab at 0x1d053a6e488>,
#  'ready': <gensim.models.keyedvectors.Vocab at 0x1d053a6e4c8>,
#  'table': <gensim.models.keyedvectors.Vocab at 0x1d053a6e508>,
#  'or': <gensim.models.keyedvectors.Vocab at 0x1d053a6e548>,
#  'stellar': <gensim.models.keyedvectors.Vocab at 0x1d053a6e588>,
#  'ros': <gensim.models.keyedvectors.Vocab at 0x1d053a6e5c8>,
#  'rare': <gensim.models.keyedvectors.Vocab at 0x1d053a6e608>,
#  'grape': <gensim.models.keyedvectors.Vocab at 0x1d053a6e648>,
#  'since': <gensim.models.keyedvectors.Vocab at 0x1d053a6e688>,
#  'Ruby': <gensim.models.keyedvectors.Vocab at 0x1d053a6e6c8>,
#  'grapefruit': <gensim.models.keyedvectors.Vocab at 0x1d053a6e708>,
#  'watermelon': <gensim.models.keyedvectors.Vocab at 0x1d053a6e748>,
#  'zest': <gensim.models.keyedvectors.Vocab at 0x1d053a6e788>,
#  'salty': <gensim.models.keyedvectors.Vocab at 0x1d053a6e7c8>,
#  'highlighted': <gensim.models.keyedvectors.Vocab at 0x1d053a6e808>,
#  'vibrant': <gensim.models.keyedvectors.Vocab at 0x1d053a6e848>,
#  'floral': <gensim.models.keyedvectors.Vocab at 0x1d053a6e888>,
#  'Alluring': <gensim.models.keyedvectors.Vocab at 0x1d053a6e8c8>,
#  'powerful': <gensim.models.keyedvectors.Vocab at 0x1d053a6e908>,
#  'grilled': <gensim.models.keyedvectors.Vocab at 0x1d053a6e948>,
#  'meat': <gensim.models.keyedvectors.Vocab at 0x1d053a6e988>,
#  'smoke': <gensim.models.keyedvectors.Vocab at 0x1d053a6e9c8>,
#  'cover': <gensim.models.keyedvectors.Vocab at 0x1d053a6ea08>,
#  'every': <gensim.models.keyedvectors.Vocab at 0x1d053a6ea48>,
#  'base': <gensim.models.keyedvectors.Vocab at 0x1d053a6ea88>,
#  'An': <gensim.models.keyedvectors.Vocab at 0x1d053a6eac8>,
#  'concentrated': <gensim.models.keyedvectors.Vocab at 0x1d053a6eb08>,
#  'Blackberry': <gensim.models.keyedvectors.Vocab at 0x1d053a6eb48>,
#  'molasses': <gensim.models.keyedvectors.Vocab at 0x1d053a6eb88>,
#  'overall': <gensim.models.keyedvectors.Vocab at 0x1d053a6ebc8>,
#  'cohesion': <gensim.models.keyedvectors.Vocab at 0x1d053a6ec08>,
#  'special': <gensim.models.keyedvectors.Vocab at 0x1d053a6ec48>,
#  'Rioja': <gensim.models.keyedvectors.Vocab at 0x1d053a6ec88>,
#  'Tarry': <gensim.models.keyedvectors.Vocab at 0x1d053a6ecc8>,
#  'cheesy': <gensim.models.keyedvectors.Vocab at 0x1d053a6ed08>,
#  'appropriate': <gensim.models.keyedvectors.Vocab at 0x1d053a6ed48>,
#  'size': <gensim.models.keyedvectors.Vocab at 0x1d053a6ed88>,
#  'In': <gensim.models.keyedvectors.Vocab at 0x1d053a6edc8>,
#  'Tinta': <gensim.models.keyedvectors.Vocab at 0x1d053a6ee08>,
#  'de': <gensim.models.keyedvectors.Vocab at 0x1d053a6ee48>,
#  'expansive': <gensim.models.keyedvectors.Vocab at 0x1d053a6ee88>,
#  'grabby': <gensim.models.keyedvectors.Vocab at 0x1d053a6eec8>,
#  'bullish': <gensim.models.keyedvectors.Vocab at 0x1d053a6ef08>,
#  'earthy': <gensim.models.keyedvectors.Vocab at 0x1d053a6ef48>,
#  'not': <gensim.models.keyedvectors.Vocab at 0x1d053a6ef88>,
#  'too': <gensim.models.keyedvectors.Vocab at 0x1d053a6efc8>,
#  'hard': <gensim.models.keyedvectors.Vocab at 0x1d053a71048>,
#  'ambitious': <gensim.models.keyedvectors.Vocab at 0x1d053a71088>,
#  'winery': <gensim.models.keyedvectors.Vocab at 0x1d053a710c8>,
#  'efforts': <gensim.models.keyedvectors.Vocab at 0x1d053a71108>,
#  'just': <gensim.models.keyedvectors.Vocab at 0x1d053a71148>,
#  'barrels': <gensim.models.keyedvectors.Vocab at 0x1d053a71188>,
#  'Clone': <gensim.models.keyedvectors.Vocab at 0x1d053a711c8>,
#  'shows': <gensim.models.keyedvectors.Vocab at 0x1d053a71208>,
#  'focused': <gensim.models.keyedvectors.Vocab at 0x1d053a71248>,
#  'nose': <gensim.models.keyedvectors.Vocab at 0x1d053a71288>,
#  'sizzles': <gensim.models.keyedvectors.Vocab at 0x1d053a712c8>,
#  'saltiness': <gensim.models.keyedvectors.Vocab at 0x1d053a71308>,
#  'lemony': <gensim.models.keyedvectors.Vocab at 0x1d053a71348>,
#  'cuts': <gensim.models.keyedvectors.Vocab at 0x1d053a71388>,
#  'brown': <gensim.models.keyedvectors.Vocab at 0x1d053a713c8>,
#  'butter': <gensim.models.keyedvectors.Vocab at 0x1d053a71408>,
#  'luxurious': <gensim.models.keyedvectors.Vocab at 0x1d053a71448>,
#  'San': <gensim.models.keyedvectors.Vocab at 0x1d053a71488>,
#  'based': <gensim.models.keyedvectors.Vocab at 0x1d053a714c8>,
#  'Adam': <gensim.models.keyedvectors.Vocab at 0x1d053a71508>,
#  'heads': <gensim.models.keyedvectors.Vocab at 0x1d053a71548>,
#  'up': <gensim.models.keyedvectors.Vocab at 0x1d053a71588>,
#  'into': <gensim.models.keyedvectors.Vocab at 0x1d053a715c8>,
#  'mountains': <gensim.models.keyedvectors.Vocab at 0x1d053a71608>,
#  'source': <gensim.models.keyedvectors.Vocab at 0x1d053a71648>,
#  'wild': <gensim.models.keyedvectors.Vocab at 0x1d053a71688>,
#  'sage': <gensim.models.keyedvectors.Vocab at 0x1d053a716c8>,
#  'eucalyptus': <gensim.models.keyedvectors.Vocab at 0x1d053a71708>,
#  'lead': <gensim.models.keyedvectors.Vocab at 0x1d053a71748>,
#  'followed': <gensim.models.keyedvectors.Vocab at 0x1d053a71788>,
#  'driven': <gensim.models.keyedvectors.Vocab at 0x1d053a717c8>,
#  'waves': <gensim.models.keyedvectors.Vocab at 0x1d053a71808>,
#  'juniper': <gensim.models.keyedvectors.Vocab at 0x1d053a71848>,
#  'pine': <gensim.models.keyedvectors.Vocab at 0x1d053a71888>,
#  'bay': <gensim.models.keyedvectors.Vocab at 0x1d053a718c8>,
#  'leaf': <gensim.models.keyedvectors.Vocab at 0x1d053a71908>,
#  'finishing': <gensim.models.keyedvectors.Vocab at 0x1d053a71948>,
#  'menthol': <gensim.models.keyedvectors.Vocab at 0x1d053a71988>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x1d053a719c8>,
#  'sensation': <gensim.models.keyedvectors.Vocab at 0x1d053a71a08>,
#  'Yields': <gensim.models.keyedvectors.Vocab at 0x1d053a71a48>,
#  'were': <gensim.models.keyedvectors.Vocab at 0x1d053a71a88>,
#  'intensity': <gensim.models.keyedvectors.Vocab at 0x1d053a71ac8>,
#  'giving': <gensim.models.keyedvectors.Vocab at 0x1d053a71b08>,
#  'potential': <gensim.models.keyedvectors.Vocab at 0x1d053a71b48>,
#  'drink': <gensim.models.keyedvectors.Vocab at 0x1d053a71b88>,
#  'least': <gensim.models.keyedvectors.Vocab at 0x1d053a71bc8>,
#  'Hickory': <gensim.models.keyedvectors.Vocab at 0x1d053a71c08>,
#  'before': <gensim.models.keyedvectors.Vocab at 0x1d053a71c48>,
#  'ending': <gensim.models.keyedvectors.Vocab at 0x1d053a71c88>,
#  'flurry': <gensim.models.keyedvectors.Vocab at 0x1d053a71cc8>,
#  'lime': <gensim.models.keyedvectors.Vocab at 0x1d053a71d08>,
#  'm': <gensim.models.keyedvectors.Vocab at 0x1d053a71d48>,
#  'Shea': <gensim.models.keyedvectors.Vocab at 0x1d053a71d88>,
#  'designate': <gensim.models.keyedvectors.Vocab at 0x1d053a71dc8>,
#  'intent': <gensim.models.keyedvectors.Vocab at 0x1d053a71e08>,
#  'showcasing': <gensim.models.keyedvectors.Vocab at 0x1d053a71e48>,
#  'pretty': <gensim.models.keyedvectors.Vocab at 0x1d053a71e88>,
#  'style': <gensim.models.keyedvectors.Vocab at 0x1d053a71ec8>,
#  'Here': <gensim.models.keyedvectors.Vocab at 0x1d053a71f08>,
#  'lovely': <gensim.models.keyedvectors.Vocab at 0x1d053a71f48>,
#  'aromatics': <gensim.models.keyedvectors.Vocab at 0x1d053a71f88>,
#  'jelly': <gensim.models.keyedvectors.Vocab at 0x1d053a71fc8>,
#  'rose': <gensim.models.keyedvectors.Vocab at 0x1d053a74048>,
#  'petals': <gensim.models.keyedvectors.Vocab at 0x1d053a74088>,
#  'run': <gensim.models.keyedvectors.Vocab at 0x1d053a740c8>,
#  'Streaks': <gensim.models.keyedvectors.Vocab at 0x1d053a74108>,
#  'more': <gensim.models.keyedvectors.Vocab at 0x1d053a74148>,
#  'generous': <gensim.models.keyedvectors.Vocab at 0x1d053a74188>,
#  'Focused': <gensim.models.keyedvectors.Vocab at 0x1d053a741c8>,
#  'captures': <gensim.models.keyedvectors.Vocab at 0x1d053a74208>,
#  'essence': <gensim.models.keyedvectors.Vocab at 0x1d053a74248>,
#  'raspberries': <gensim.models.keyedvectors.Vocab at 0x1d053a74288>,
#  'Aged': <gensim.models.keyedvectors.Vocab at 0x1d053a742c8>,
#  'strong': <gensim.models.keyedvectors.Vocab at 0x1d053a74308>,
#  'vein': <gensim.models.keyedvectors.Vocab at 0x1d053a74348>,
#  'broaden': <gensim.models.keyedvectors.Vocab at 0x1d053a74388>,
#  'out': <gensim.models.keyedvectors.Vocab at 0x1d053a743c8>,
#  'penetrate': <gensim.models.keyedvectors.Vocab at 0x1d053a74408>,
#  'highlights': <gensim.models.keyedvectors.Vocab at 0x1d053a74448>,
#  'cinnamon': <gensim.models.keyedvectors.Vocab at 0x1d053a74488>,
#  'decant': <gensim.models.keyedvectors.Vocab at 0x1d053a744c8>,
#  'if': <gensim.models.keyedvectors.Vocab at 0x1d053a74508>,
#  'you': <gensim.models.keyedvectors.Vocab at 0x1d053a74548>,
#  'want': <gensim.models.keyedvectors.Vocab at 0x1d053a74588>,
#  'expression': <gensim.models.keyedvectors.Vocab at 0x1d053a745c8>,
#  'Cranberry': <gensim.models.keyedvectors.Vocab at 0x1d053a74608>,
#  'rhubarb': <gensim.models.keyedvectors.Vocab at 0x1d053a74648>,
#  'anise': <gensim.models.keyedvectors.Vocab at 0x1d053a74688>,
#  'crushed': <gensim.models.keyedvectors.Vocab at 0x1d053a746c8>,
#  'slate': <gensim.models.keyedvectors.Vocab at 0x1d053a74708>,
#  'show': <gensim.models.keyedvectors.Vocab at 0x1d053a74748>,
#  'always': <gensim.models.keyedvectors.Vocab at 0x1d053a74788>,
#  'abounds': <gensim.models.keyedvectors.Vocab at 0x1d053a747c8>,
#  'energy': <gensim.models.keyedvectors.Vocab at 0x1d053a74808>,
#  'driving': <gensim.models.keyedvectors.Vocab at 0x1d053a74848>,
#  'accented': <gensim.models.keyedvectors.Vocab at 0x1d053a74888>,
#  'loam': <gensim.models.keyedvectors.Vocab at 0x1d053a748c8>,
#  'fennel': <gensim.models.keyedvectors.Vocab at 0x1d053a74908>,
#  'oregano': <gensim.models.keyedvectors.Vocab at 0x1d053a74948>,
#  'compellingly': <gensim.models.keyedvectors.Vocab at 0x1d053a74988>,
#  'round': <gensim.models.keyedvectors.Vocab at 0x1d053a749c8>,
#  'Rocks': <gensim.models.keyedvectors.Vocab at 0x1d053a74a08>,
#  'District': <gensim.models.keyedvectors.Vocab at 0x1d053a74a48>,
#  'brings': <gensim.models.keyedvectors.Vocab at 0x1d053a74a88>,
#  'earth': <gensim.models.keyedvectors.Vocab at 0x1d053a74ac8>,
#  'olive': <gensim.models.keyedvectors.Vocab at 0x1d053a74b08>,
#  'brine': <gensim.models.keyedvectors.Vocab at 0x1d053a74b48>,
#  'tapenade': <gensim.models.keyedvectors.Vocab at 0x1d053a74b88>,
#  'green': <gensim.models.keyedvectors.Vocab at 0x1d053a74bc8>,
#  'lilies': <gensim.models.keyedvectors.Vocab at 0x1d053a74c08>,
#  'gravel': <gensim.models.keyedvectors.Vocab at 0x1d053a74c48>,
#  'smoked': <gensim.models.keyedvectors.Vocab at 0x1d053a74c88>,
#  'charcuterie': <gensim.models.keyedvectors.Vocab at 0x1d053a74cc8>,
#  'blue': <gensim.models.keyedvectors.Vocab at 0x1d053a74d08>,
#  'don': <gensim.models.keyedvectors.Vocab at 0x1d053a74d48>,
#  't': <gensim.models.keyedvectors.Vocab at 0x1d053a74d88>,
#  'hold': <gensim.models.keyedvectors.Vocab at 0x1d053a74dc8>,
#  'back': <gensim.models.keyedvectors.Vocab at 0x1d053a74e08>,
#  'bringing': <gensim.models.keyedvectors.Vocab at 0x1d053a74e48>,
#  'sense': <gensim.models.keyedvectors.Vocab at 0x1d053a74e88>,
#  'detail': <gensim.models.keyedvectors.Vocab at 0x1d053a74ec8>,
#  'completely': <gensim.models.keyedvectors.Vocab at 0x1d053a74f08>,
#  'demands': <gensim.models.keyedvectors.Vocab at 0x1d053a74f48>,
#  'your': <gensim.models.keyedvectors.Vocab at 0x1d053a74f88>,
#  'attention': <gensim.models.keyedvectors.Vocab at 0x1d053a74fc8>,
#  'Bulgarian': <gensim.models.keyedvectors.Vocab at 0x1d053a77048>,
#  'presents': <gensim.models.keyedvectors.Vocab at 0x1d053a77088>,
#  'suggestions': <gensim.models.keyedvectors.Vocab at 0x1d053a770c8>,
#  'freshly': <gensim.models.keyedvectors.Vocab at 0x1d053a77108>,
#  'ground': <gensim.models.keyedvectors.Vocab at 0x1d053a77148>,
#  'pepper': <gensim.models.keyedvectors.Vocab at 0x1d053a77188>,
#  'whiff': <gensim.models.keyedvectors.Vocab at 0x1d053a771c8>,
#  'soft': <gensim.models.keyedvectors.Vocab at 0x1d053a77208>,
#  'mingling': <gensim.models.keyedvectors.Vocab at 0x1d053a77248>,
#  'Steely': <gensim.models.keyedvectors.Vocab at 0x1d053a77288>,
#  'perfumed': <gensim.models.keyedvectors.Vocab at 0x1d053a772c8>,
#  'sees': <gensim.models.keyedvectors.Vocab at 0x1d053a77308>,
#  'only': <gensim.models.keyedvectors.Vocab at 0x1d053a77348>,
#  'remaining': <gensim.models.keyedvectors.Vocab at 0x1d053a77388>,
#  'vibrantly': <gensim.models.keyedvectors.Vocab at 0x1d053a773c8>,
#  'Baked': <gensim.models.keyedvectors.Vocab at 0x1d053a77408>,
#  'apple': <gensim.models.keyedvectors.Vocab at 0x1d053a77448>,
#  'lemon': <gensim.models.keyedvectors.Vocab at 0x1d053a77488>,
#  'pith': <gensim.models.keyedvectors.Vocab at 0x1d053a774c8>,
#  'veer': <gensim.models.keyedvectors.Vocab at 0x1d053a77508>,
#  'spiciness': <gensim.models.keyedvectors.Vocab at 0x1d053a77548>,
#  'brash': <gensim.models.keyedvectors.Vocab at 0x1d053a77588>,
#  'loud': <gensim.models.keyedvectors.Vocab at 0x1d053a775c8>,
#  'Underbrush': <gensim.models.keyedvectors.Vocab at 0x1d053a77608>,
#  'scorched': <gensim.models.keyedvectors.Vocab at 0x1d053a77648>,
#  'steeped': <gensim.models.keyedvectors.Vocab at 0x1d053a77688>,
#  'spirits': <gensim.models.keyedvectors.Vocab at 0x1d053a776c8>,
#  'some': <gensim.models.keyedvectors.Vocab at 0x1d053a77708>,
#  'unfold': <gensim.models.keyedvectors.Vocab at 0x1d053a77748>,
#  'big': <gensim.models.keyedvectors.Vocab at 0x1d053a77788>,
#  'chewy': <gensim.models.keyedvectors.Vocab at 0x1d053a777c8>,
#  'doles': <gensim.models.keyedvectors.Vocab at 0x1d053a77808>,
#  'jam': <gensim.models.keyedvectors.Vocab at 0x1d053a77848>,
#  'alongside': <gensim.models.keyedvectors.Vocab at 0x1d053a77888>,
#  'firm': <gensim.models.keyedvectors.Vocab at 0x1d053a778c8>,
#  'detect': <gensim.models.keyedvectors.Vocab at 0x1d053a77908>,
#  'warmth': <gensim.models.keyedvectors.Vocab at 0x1d053a77948>,
#  'alcohol': <gensim.models.keyedvectors.Vocab at 0x1d053a77988>,
#  'Pale': <gensim.models.keyedvectors.Vocab at 0x1d053a779c8>,
#  'nutty': <gensim.models.keyedvectors.Vocab at 0x1d053a77a08>,
#  'character': <gensim.models.keyedvectors.Vocab at 0x1d053a77a48>,
#  'warm': <gensim.models.keyedvectors.Vocab at 0x1d053a77a88>,
#  'rounded': <gensim.models.keyedvectors.Vocab at 0x1d053a77ac8>,
#  'aftertaste': <gensim.models.keyedvectors.Vocab at 0x1d053a77b08>,
#  'cellars': <gensim.models.keyedvectors.Vocab at 0x1d053a77b48>,
#  'Saumur': <gensim.models.keyedvectors.Vocab at 0x1d053a77b88>,
#  'Loire': <gensim.models.keyedvectors.Vocab at 0x1d053a77bc8>,
#  'river': <gensim.models.keyedvectors.Vocab at 0x1d053a77c08>,
#  'entice': <gensim.models.keyedvectors.Vocab at 0x1d053a77c48>,
#  'wet': <gensim.models.keyedvectors.Vocab at 0x1d053a77c88>,
#  'stone': <gensim.models.keyedvectors.Vocab at 0x1d053a77cc8>,
#  'honeysuckle': <gensim.models.keyedvectors.Vocab at 0x1d053a77d08>,
#  'chamomile': <gensim.models.keyedvectors.Vocab at 0x1d053a77d48>,
#  'feel': <gensim.models.keyedvectors.Vocab at 0x1d053a77d88>,
#  'showing': <gensim.models.keyedvectors.Vocab at 0x1d053a77dc8>,
#  'Forest': <gensim.models.keyedvectors.Vocab at 0x1d053a77e08>,
#  'floor': <gensim.models.keyedvectors.Vocab at 0x1d053a77e48>,
#  'tilled': <gensim.models.keyedvectors.Vocab at 0x1d053a77e88>,
#  'soil': <gensim.models.keyedvectors.Vocab at 0x1d053a77ec8>,
#  'combine': <gensim.models.keyedvectors.Vocab at 0x1d053a77f08>,
#  'grained': <gensim.models.keyedvectors.Vocab at 0x1d053a77f48>,
#  'grip': <gensim.models.keyedvectors.Vocab at 0x1d053a77f88>,
#  'accent': <gensim.models.keyedvectors.Vocab at 0x1d053a77fc8>,
#  'melon': <gensim.models.keyedvectors.Vocab at 0x1d053a7c048>,
#  'flabby': <gensim.models.keyedvectors.Vocab at 0x1d053a7c088>,
#  'forest': <gensim.models.keyedvectors.Vocab at 0x1d053a7c0c8>,
#  'violet': <gensim.models.keyedvectors.Vocab at 0x1d053a7c108>,
#  'star': <gensim.models.keyedvectors.Vocab at 0x1d053a7c148>,
#  'drive': <gensim.models.keyedvectors.Vocab at 0x1d053a7c188>,
#  'classic': <gensim.models.keyedvectors.Vocab at 0x1d053a7c1c8>,
#  'Tuscan': <gensim.models.keyedvectors.Vocab at 0x1d053a7c208>,
#  'charming': <gensim.models.keyedvectors.Vocab at 0x1d053a7c248>,
#  'boasts': <gensim.models.keyedvectors.Vocab at 0x1d053a7c288>,
#  'easy': <gensim.models.keyedvectors.Vocab at 0x1d053a7c2c8>,
#  'chopped': <gensim.models.keyedvectors.Vocab at 0x1d053a7c308>,
#  'mint': <gensim.models.keyedvectors.Vocab at 0x1d053a7c348>,
#  'There': <gensim.models.keyedvectors.Vocab at 0x1d053a7c388>,
#  'isn': <gensim.models.keyedvectors.Vocab at 0x1d053a7c3c8>,
#  'much': <gensim.models.keyedvectors.Vocab at 0x1d053a7c408>,
#  'delivers': <gensim.models.keyedvectors.Vocab at 0x1d053a7c448>,
#  'Polished': <gensim.models.keyedvectors.Vocab at 0x1d053a7c488>,
#  'provide': <gensim.models.keyedvectors.Vocab at 0x1d053a7c4c8>,
#  'framework': <gensim.models.keyedvectors.Vocab at 0x1d053a7c508>,
#  'Earthy': <gensim.models.keyedvectors.Vocab at 0x1d053a7c548>,
#  'score': <gensim.models.keyedvectors.Vocab at 0x1d053a7c588>,
#  'points': <gensim.models.keyedvectors.Vocab at 0x1d053a7c5c8>,
#  'being': <gensim.models.keyedvectors.Vocab at 0x1d053a7c608>,
#  'clear': <gensim.models.keyedvectors.Vocab at 0x1d053a7c648>,
#  'direct': <gensim.models.keyedvectors.Vocab at 0x1d053a7c688>,
#  'Menc': <gensim.models.keyedvectors.Vocab at 0x1d053a7c6c8>,
#  'Lightly': <gensim.models.keyedvectors.Vocab at 0x1d053a7c708>,
#  'briny': <gensim.models.keyedvectors.Vocab at 0x1d053a7c748>,
#  'steady': <gensim.models.keyedvectors.Vocab at 0x1d053a7c788>,
#  'dash': <gensim.models.keyedvectors.Vocab at 0x1d053a7c7c8>,
#  'comes': <gensim.models.keyedvectors.Vocab at 0x1d053a7c808>,
#  'across': <gensim.models.keyedvectors.Vocab at 0x1d053a7c848>,
#  'wide': <gensim.models.keyedvectors.Vocab at 0x1d053a7c888>,
#  'exudes': <gensim.models.keyedvectors.Vocab at 0x1d053a7c8c8>,
#  'oily': <gensim.models.keyedvectors.Vocab at 0x1d053a7c908>,
#  'toffee': <gensim.models.keyedvectors.Vocab at 0x1d053a7c948>,
#  'plump': <gensim.models.keyedvectors.Vocab at 0x1d053a7c988>,
#  'overly': <gensim.models.keyedvectors.Vocab at 0x1d053a7c9c8>,
#  'cutting': <gensim.models.keyedvectors.Vocab at 0x1d053a7ca08>,
#  'demanding': <gensim.models.keyedvectors.Vocab at 0x1d053a7ca48>,
#  'lightly': <gensim.models.keyedvectors.Vocab at 0x1d053a7ca88>,
#  'salted': <gensim.models.keyedvectors.Vocab at 0x1d053a7cac8>,
#  'nuts': <gensim.models.keyedvectors.Vocab at 0x1d053a7cb08>,
#  'buttered': <gensim.models.keyedvectors.Vocab at 0x1d053a7cb48>,
#  'end': <gensim.models.keyedvectors.Vocab at 0x1d053a7cb88>,
#  'peanut': <gensim.models.keyedvectors.Vocab at 0x1d053a7cbc8>,
#  'flowers': <gensim.models.keyedvectors.Vocab at 0x1d053a7cc08>,
#  'herbs': <gensim.models.keyedvectors.Vocab at 0x1d053a7cc48>,
#  'tightly': <gensim.models.keyedvectors.Vocab at 0x1d053a7cc88>,
#  'coiled': <gensim.models.keyedvectors.Vocab at 0x1d053a7ccc8>,
#  'acids': <gensim.models.keyedvectors.Vocab at 0x1d053a7cd08>,
#  'pleasing': <gensim.models.keyedvectors.Vocab at 0x1d053a7cd48>,
#  'example': <gensim.models.keyedvectors.Vocab at 0x1d053a7cd88>,
#  'variety': <gensim.models.keyedvectors.Vocab at 0x1d053a7cdc8>,
#  'skinned': <gensim.models.keyedvectors.Vocab at 0x1d053a7ce08>,
#  'clove': <gensim.models.keyedvectors.Vocab at 0x1d053a7ce48>,
#  'profile': <gensim.models.keyedvectors.Vocab at 0x1d053a7ce88>,
#  'Cornas': <gensim.models.keyedvectors.Vocab at 0x1d053a7cec8>,
#  'reminiscent': <gensim.models.keyedvectors.Vocab at 0x1d053a7cf08>,
#  'fudge': <gensim.models.keyedvectors.Vocab at 0x1d053a7cf48>,
#  'plummy': <gensim.models.keyedvectors.Vocab at 0x1d053a7cf88>,
#  'dusty': <gensim.models.keyedvectors.Vocab at 0x1d053a7cfc8>,
#  'blend': <gensim.models.keyedvectors.Vocab at 0x1d053a7f048>,
# ...
#  'support': <gensim.models.keyedvectors.Vocab at 0x1d053a7f148>,
#  'meld': <gensim.models.keyedvectors.Vocab at 0x1d053a7f188>,
#  'Blended': <gensim.models.keyedvectors.Vocab at 0x1d053a7f1c8>,
#  'Malbec': <gensim.models.keyedvectors.Vocab at 0x1d053a7f208>,
#  'Cabernet': <gensim.models.keyedvectors.Vocab at 0x1d053a7f248>,
#  'Franc': <gensim.models.keyedvectors.Vocab at 0x1d053a7f288>,
#  'Petit': <gensim.models.keyedvectors.Vocab at 0x1d053a7f2c8>,
#  'Verdot': <gensim.models.keyedvectors.Vocab at 0x1d053a7f308>,
#  'perennial': <gensim.models.keyedvectors.Vocab at 0x1d053a7f348>,
#  'sister': <gensim.models.keyedvectors.Vocab at 0x1d053a7f388>,
#  'brand': <gensim.models.keyedvectors.Vocab at 0x1d053a7f3c8>,
#  'Cuvaison': <gensim.models.keyedvectors.Vocab at 0x1d053a7f408>,
#  'pillowy': <gensim.models.keyedvectors.Vocab at 0x1d053a7f448>,
#  'tar': <gensim.models.keyedvectors.Vocab at 0x1d053a7f488>,
#  'suggesting': <gensim.models.keyedvectors.Vocab at 0x1d053a7f4c8>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x1d053a7f508>,
#  'match': <gensim.models.keyedvectors.Vocab at 0x1d053a7f548>,
#  'cooking': <gensim.models.keyedvectors.Vocab at 0x1d053a7f588>,
#  'accessible': <gensim.models.keyedvectors.Vocab at 0x1d053a7f5c8>,
#  'so': <gensim.models.keyedvectors.Vocab at 0x1d053a7f608>,
#  'no': <gensim.models.keyedvectors.Vocab at 0x1d053a7f648>,
#  'need': <gensim.models.keyedvectors.Vocab at 0x1d053a7f688>,
#  'Best': <gensim.models.keyedvectors.Vocab at 0x1d053a7f6c8>,
#  'initially': <gensim.models.keyedvectors.Vocab at 0x1d053a7f708>,
#  'under': <gensim.models.keyedvectors.Vocab at 0x1d053a7f748>,
#  'tight': <gensim.models.keyedvectors.Vocab at 0x1d053a7f788>,
#  'simultaneously': <gensim.models.keyedvectors.Vocab at 0x1d053a7f7c8>,
#  'robust': <gensim.models.keyedvectors.Vocab at 0x1d053a7f808>,
#  'cake': <gensim.models.keyedvectors.Vocab at 0x1d053a7f848>,
#  'hearty': <gensim.models.keyedvectors.Vocab at 0x1d053a7f888>,
#  'closes': <gensim.models.keyedvectors.Vocab at 0x1d053a7f8c8>,
#  'structured': <gensim.models.keyedvectors.Vocab at 0x1d053a7f908>,
#  'weight': <gensim.models.keyedvectors.Vocab at 0x1d053a7f948>,
#  'almost': <gensim.models.keyedvectors.Vocab at 0x1d053a7f988>,
#  'will': <gensim.models.keyedvectors.Vocab at 0x1d053a7f9c8>,
#  'soften': <gensim.models.keyedvectors.Vocab at 0x1d053a7fa08>,
#  'next': <gensim.models.keyedvectors.Vocab at 0x1d053a7fa48>,
#  'few': <gensim.models.keyedvectors.Vocab at 0x1d053a7fa88>,
#  'Full': <gensim.models.keyedvectors.Vocab at 0x1d053a7fac8>,
#  'drinkable': <gensim.models.keyedvectors.Vocab at 0x1d053a7fb08>,
#  'be': <gensim.models.keyedvectors.Vocab at 0x1d053a7fb48>,
#  'better': <gensim.models.keyedvectors.Vocab at 0x1d053a7fb88>,
#  'lifted': <gensim.models.keyedvectors.Vocab at 0x1d053a7fbc8>,
#  'richer': <gensim.models.keyedvectors.Vocab at 0x1d053a7fc08>,
#  'apricot': <gensim.models.keyedvectors.Vocab at 0x1d053a7fc48>,
#  'Still': <gensim.models.keyedvectors.Vocab at 0x1d053a7fc88>,
#  'young': <gensim.models.keyedvectors.Vocab at 0x1d053a7fcc8>,
#  'going': <gensim.models.keyedvectors.Vocab at 0x1d053a7fd08>,
#  'fruity': <gensim.models.keyedvectors.Vocab at 0x1d053a7fd48>,
#  'name': <gensim.models.keyedvectors.Vocab at 0x1d053a7fd88>,
#  'means': <gensim.models.keyedvectors.Vocab at 0x1d053a7fdc8>,
#  'parcel': <gensim.models.keyedvectors.Vocab at 0x1d053a7fe08>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x1d053a7fe48>,
#  'day': <gensim.models.keyedvectors.Vocab at 0x1d053a7fe88>,
#  'light': <gensim.models.keyedvectors.Vocab at 0x1d053a7fec8>,
#  'smoky': <gensim.models.keyedvectors.Vocab at 0x1d053a7ff08>,
#  'slowly': <gensim.models.keyedvectors.Vocab at 0x1d053a7ff48>,
#  'lot': <gensim.models.keyedvectors.Vocab at 0x1d053a7ff88>,
#  'priced': <gensim.models.keyedvectors.Vocab at 0x1d053a7ffc8>,
#  'several': <gensim.models.keyedvectors.Vocab at 0x1d053a82048>,
#  'regional': <gensim.models.keyedvectors.Vocab at 0x1d053a82088>,
#  'taste': <gensim.models.keyedvectors.Vocab at 0x1d053a820c8>,
#  'expands': <gensim.models.keyedvectors.Vocab at 0x1d053a82108>,
#  'meet': <gensim.models.keyedvectors.Vocab at 0x1d053a82148>,
#  'crowd': <gensim.models.keyedvectors.Vocab at 0x1d053a82188>,
#  'measured': <gensim.models.keyedvectors.Vocab at 0x1d053a821c8>,
#  'Grand': <gensim.models.keyedvectors.Vocab at 0x1d053a82208>,
#  'Ciel': <gensim.models.keyedvectors.Vocab at 0x1d053a82248>,
#  'du': <gensim.models.keyedvectors.Vocab at 0x1d053a82288>,
#  'Cheval': <gensim.models.keyedvectors.Vocab at 0x1d053a822c8>,
#  'Klipsun': <gensim.models.keyedvectors.Vocab at 0x1d053a82308>,
#  'front': <gensim.models.keyedvectors.Vocab at 0x1d053a82348>,
#  'Delicious': <gensim.models.keyedvectors.Vocab at 0x1d053a82388>,
#  'biodynamically': <gensim.models.keyedvectors.Vocab at 0x1d053a823c8>,
#  'grown': <gensim.models.keyedvectors.Vocab at 0x1d053a82408>,
#  'grapes': <gensim.models.keyedvectors.Vocab at 0x1d053a82448>,
#  'moment': <gensim.models.keyedvectors.Vocab at 0x1d053a82488>,
#  'needs': <gensim.models.keyedvectors.Vocab at 0x1d053a824c8>,
#  'While': <gensim.models.keyedvectors.Vocab at 0x1d053a82508>,
#  'exuberantly': <gensim.models.keyedvectors.Vocab at 0x1d053a82548>,
#  'tropical': <gensim.models.keyedvectors.Vocab at 0x1d053a82588>,
#  'crystalline': <gensim.models.keyedvectors.Vocab at 0x1d053a825c8>,
#  'edge': <gensim.models.keyedvectors.Vocab at 0x1d053a82608>,
#  'dry': <gensim.models.keyedvectors.Vocab at 0x1d053a82648>,
#  'Riesling': <gensim.models.keyedvectors.Vocab at 0x1d053a82688>,
#  'renders': <gensim.models.keyedvectors.Vocab at 0x1d053a826c8>,
#  'especially': <gensim.models.keyedvectors.Vocab at 0x1d053a82708>,
#  'refreshing': <gensim.models.keyedvectors.Vocab at 0x1d053a82748>,
#  'footed': <gensim.models.keyedvectors.Vocab at 0x1d053a82788>,
#  'brightened': <gensim.models.keyedvectors.Vocab at 0x1d053a827c8>,
#  'honey': <gensim.models.keyedvectors.Vocab at 0x1d053a82808>,
#  'half': <gensim.models.keyedvectors.Vocab at 0x1d053a82848>,
#  'cherries': <gensim.models.keyedvectors.Vocab at 0x1d053a82888>,
#  'minerals': <gensim.models.keyedvectors.Vocab at 0x1d053a828c8>,
#  'plush': <gensim.models.keyedvectors.Vocab at 0x1d053a82908>,
#  'feeling': <gensim.models.keyedvectors.Vocab at 0x1d053a82948>,
#  'backed': <gensim.models.keyedvectors.Vocab at 0x1d053a82988>,
#  'Merlot': <gensim.models.keyedvectors.Vocab at 0x1d053a829c8>,
#  'Sauvignon': <gensim.models.keyedvectors.Vocab at 0x1d053a82a08>,
#  'Syrah': <gensim.models.keyedvectors.Vocab at 0x1d053a82a48>,
#  'roasted': <gensim.models.keyedvectors.Vocab at 0x1d053a82a88>,
#  'bean': <gensim.models.keyedvectors.Vocab at 0x1d053a82ac8>,
#  'woodland': <gensim.models.keyedvectors.Vocab at 0x1d053a82b08>,
#  'Concentrated': <gensim.models.keyedvectors.Vocab at 0x1d053a82b48>,
#  'heat': <gensim.models.keyedvectors.Vocab at 0x1d053a82b88>,
#  'lends': <gensim.models.keyedvectors.Vocab at 0x1d053a82bc8>,
#  'sizzle': <gensim.models.keyedvectors.Vocab at 0x1d053a82c08>,
#  'estate': <gensim.models.keyedvectors.Vocab at 0x1d053a82c48>,
#  'Pinot': <gensim.models.keyedvectors.Vocab at 0x1d053a82c88>,
#  'Noir': <gensim.models.keyedvectors.Vocab at 0x1d053a82cc8>,
#  'solid': <gensim.models.keyedvectors.Vocab at 0x1d053a82d08>,
#  'value': <gensim.models.keyedvectors.Vocab at 0x1d053a82d48>,
#  'boutique': <gensim.models.keyedvectors.Vocab at 0x1d053a82d88>,
#  'offerings': <gensim.models.keyedvectors.Vocab at 0x1d053a82dc8>,
#  'cushioning': <gensim.models.keyedvectors.Vocab at 0x1d053a82e08>,
#  'flesh': <gensim.models.keyedvectors.Vocab at 0x1d053a82e48>,
#  'wrapped': <gensim.models.keyedvectors.Vocab at 0x1d053a82e88>,
#  'around': <gensim.models.keyedvectors.Vocab at 0x1d053a82ec8>,
#  'backbone': <gensim.models.keyedvectors.Vocab at 0x1d053a82f08>,
#  'earthier': <gensim.models.keyedvectors.Vocab at 0x1d053a82f48>,
#  'parsnip': <gensim.models.keyedvectors.Vocab at 0x1d053a82f88>,
#  'Smoky': <gensim.models.keyedvectors.Vocab at 0x1d053a82fc8>,
#  'cut': <gensim.models.keyedvectors.Vocab at 0x1d053a85048>,
#  'form': <gensim.models.keyedvectors.Vocab at 0x1d053a85088>,
#  'welcoming': <gensim.models.keyedvectors.Vocab at 0x1d053a850c8>,
#  'bouquet': <gensim.models.keyedvectors.Vocab at 0x1d053a85108>,
#  'albeit': <gensim.models.keyedvectors.Vocab at 0x1d053a85148>,
#  'tartaric': <gensim.models.keyedvectors.Vocab at 0x1d053a85188>,
#  'Oaky': <gensim.models.keyedvectors.Vocab at 0x1d053a851c8>,
#  'agreeable': <gensim.models.keyedvectors.Vocab at 0x1d053a85208>,
#  'northern': <gensim.models.keyedvectors.Vocab at 0x1d053a85248>,
#  'Fourchaume': <gensim.models.keyedvectors.Vocab at 0x1d053a85288>,
#  'Premier': <gensim.models.keyedvectors.Vocab at 0x1d053a852c8>,
#  'Cru': <gensim.models.keyedvectors.Vocab at 0x1d053a85308>,
#  'called': <gensim.models.keyedvectors.Vocab at 0x1d053a85348>,
#  'because': <gensim.models.keyedvectors.Vocab at 0x1d053a85388>,
#  'where': <gensim.models.keyedvectors.Vocab at 0x1d053a853c8>,
#  'local': <gensim.models.keyedvectors.Vocab at 0x1d053a85408>,
#  'justice': <gensim.models.keyedvectors.Vocab at 0x1d053a85448>,
#  'often': <gensim.models.keyedvectors.Vocab at 0x1d053a85488>,
#  'produces': <gensim.models.keyedvectors.Vocab at 0x1d053a854c8>,
#  'cooler': <gensim.models.keyedvectors.Vocab at 0x1d053a85508>,
#  'wines': <gensim.models.keyedvectors.Vocab at 0x1d053a85548>,
#  'such': <gensim.models.keyedvectors.Vocab at 0x1d053a85588>,
#  'bread': <gensim.models.keyedvectors.Vocab at 0x1d053a855c8>,
#  'strongly': <gensim.models.keyedvectors.Vocab at 0x1d053a85608>,
#  'does': <gensim.models.keyedvectors.Vocab at 0x1d053a85648>,
#  'shouldn': <gensim.models.keyedvectors.Vocab at 0x1d053a85688>,
#  'drunk': <gensim.models.keyedvectors.Vocab at 0x1d053a856c8>,
#  'super': <gensim.models.keyedvectors.Vocab at 0x1d053a85708>,
#  'very': <gensim.models.keyedvectors.Vocab at 0x1d053a85748>,
#  'allow': <gensim.models.keyedvectors.Vocab at 0x1d053a85788>,
#  'age': <gensim.models.keyedvectors.Vocab at 0x1d053a857c8>,
#  'combination': <gensim.models.keyedvectors.Vocab at 0x1d053a85808>,
#  'skin': <gensim.models.keyedvectors.Vocab at 0x1d053a85848>,
#  'leave': <gensim.models.keyedvectors.Vocab at 0x1d053a85888>,
#  'until': <gensim.models.keyedvectors.Vocab at 0x1d053a858c8>,
#  'Fresh': <gensim.models.keyedvectors.Vocab at 0x1d053a85908>,
#  'boysenberries': <gensim.models.keyedvectors.Vocab at 0x1d053a85948>,
#  'sorbet': <gensim.models.keyedvectors.Vocab at 0x1d053a85988>,
#  'tarragon': <gensim.models.keyedvectors.Vocab at 0x1d053a859c8>,
#  'dill': <gensim.models.keyedvectors.Vocab at 0x1d053a85a08>,
#  'hot': <gensim.models.keyedvectors.Vocab at 0x1d053a85a48>,
#  'area': <gensim.models.keyedvectors.Vocab at 0x1d053a85a88>,
#  'between': <gensim.models.keyedvectors.Vocab at 0x1d053a85ac8>,
#  'Morgan': <gensim.models.keyedvectors.Vocab at 0x1d053a85b08>,
#  'Hill': <gensim.models.keyedvectors.Vocab at 0x1d053a85b48>,
#  'prominent': <gensim.models.keyedvectors.Vocab at 0x1d053a85b88>,
#  'relatively': <gensim.models.keyedvectors.Vocab at 0x1d053a85bc8>,
#  'boysenberry': <gensim.models.keyedvectors.Vocab at 0x1d053a85c08>,
#  'steely': <gensim.models.keyedvectors.Vocab at 0x1d053a85c48>,
#  'Chablis': <gensim.models.keyedvectors.Vocab at 0x1d053a85c88>,
#  'apparent': <gensim.models.keyedvectors.Vocab at 0x1d053a85cc8>,
#  'flavored': <gensim.models.keyedvectors.Vocab at 0x1d053a85d08>,
#  'freshness': <gensim.models.keyedvectors.Vocab at 0x1d053a85d48>,
#  'heart': <gensim.models.keyedvectors.Vocab at 0x1d053a85d88>,
#  'needing': <gensim.models.keyedvectors.Vocab at 0x1d053a85dc8>,
#  'monumental': <gensim.models.keyedvectors.Vocab at 0x1d053a85e08>,
#  'Atlas': <gensim.models.keyedvectors.Vocab at 0x1d053a85e48>,
#  'Peak': <gensim.models.keyedvectors.Vocab at 0x1d053a85e88>,
#  'wound': <gensim.models.keyedvectors.Vocab at 0x1d053a85ec8>,
#  'solidly': <gensim.models.keyedvectors.Vocab at 0x1d053a85f08>,
#  'constructed': <gensim.models.keyedvectors.Vocab at 0x1d053a85f48>,
#  'mountain': <gensim.models.keyedvectors.Vocab at 0x1d053a85f88>,
#  'Cab': <gensim.models.keyedvectors.Vocab at 0x1d053a85fc8>,
#  'blended': <gensim.models.keyedvectors.Vocab at 0x1d053a8a048>,
#  'handful': <gensim.models.keyedvectors.Vocab at 0x1d053a8a088>,
#  'Tobacco': <gensim.models.keyedvectors.Vocab at 0x1d053a8a0c8>,
#  'sliver': <gensim.models.keyedvectors.Vocab at 0x1d053a8a108>,
#  'coconut': <gensim.models.keyedvectors.Vocab at 0x1d053a8a148>,
#  'intermingle': <gensim.models.keyedvectors.Vocab at 0x1d053a8a188>,
#  'whole': <gensim.models.keyedvectors.Vocab at 0x1d053a8a1c8>,
#  'benefit': <gensim.models.keyedvectors.Vocab at 0x1d053a8a208>,
#  'cellaring': <gensim.models.keyedvectors.Vocab at 0x1d053a8a248>,
#  'Big': <gensim.models.keyedvectors.Vocab at 0x1d053a8a288>,
#  'bold': <gensim.models.keyedvectors.Vocab at 0x1d053a8a2c8>,
#  'builds': <gensim.models.keyedvectors.Vocab at 0x1d053a8a308>,
#  'upon': <gensim.models.keyedvectors.Vocab at 0x1d053a8a348>,
#  'substantial': <gensim.models.keyedvectors.Vocab at 0x1d053a8a388>,
#  'supporting': <gensim.models.keyedvectors.Vocab at 0x1d053a8a3c8>,
#  'knitting': <gensim.models.keyedvectors.Vocab at 0x1d053a8a408>,
#  'thick': <gensim.models.keyedvectors.Vocab at 0x1d053a8a448>,
#  'Give': <gensim.models.keyedvectors.Vocab at 0x1d053a8a488>,
#  'couple': <gensim.models.keyedvectors.Vocab at 0x1d053a8a4c8>,
#  'bottle': <gensim.models.keyedvectors.Vocab at 0x1d053a8a508>,
#  'juiciness': <gensim.models.keyedvectors.Vocab at 0x1d053a8a548>,
#  'spark': <gensim.models.keyedvectors.Vocab at 0x1d053a8a588>,
#  'celebration': <gensim.models.keyedvectors.Vocab at 0x1d053a8a5c8>,
#  'vintage': <gensim.models.keyedvectors.Vocab at 0x1d053a8a608>,
#  'appellation': <gensim.models.keyedvectors.Vocab at 0x1d053a8a648>,
#  'case': <gensim.models.keyedvectors.Vocab at 0x1d053a8a688>,
#  'forwardness': <gensim.models.keyedvectors.Vocab at 0x1d053a8a6c8>,
#  'highlight': <gensim.models.keyedvectors.Vocab at 0x1d053a8a708>,
#  'depth': <gensim.models.keyedvectors.Vocab at 0x1d053a8a748>,
#  'small': <gensim.models.keyedvectors.Vocab at 0x1d053a8a788>,
#  'amounts': <gensim.models.keyedvectors.Vocab at 0x1d053a8a7c8>,
#  'Soft': <gensim.models.keyedvectors.Vocab at 0x1d053a8a808>,
#  'crafts': <gensim.models.keyedvectors.Vocab at 0x1d053a8a848>,
#  'draws': <gensim.models.keyedvectors.Vocab at 0x1d053a8a888>,
#  'sites': <gensim.models.keyedvectors.Vocab at 0x1d053a8a8c8>,
#  'including': <gensim.models.keyedvectors.Vocab at 0x1d053a8a908>,
#  'Ranch': <gensim.models.keyedvectors.Vocab at 0x1d053a8a948>,
#  'climate': <gensim.models.keyedvectors.Vocab at 0x1d053a8a988>,
#  'minimally': <gensim.models.keyedvectors.Vocab at 0x1d053a8a9c8>,
#  'sun': <gensim.models.keyedvectors.Vocab at 0x1d053a8aa08>,
#  'marinated': <gensim.models.keyedvectors.Vocab at 0x1d053a8aa48>,
#  'game': <gensim.models.keyedvectors.Vocab at 0x1d053a8aa88>,
#  'Massively': <gensim.models.keyedvectors.Vocab at 0x1d053a8aac8>,
#  'huge': <gensim.models.keyedvectors.Vocab at 0x1d053a8ab08>,
#  'convey': <gensim.models.keyedvectors.Vocab at 0x1d053a8ab48>,
#  'impression': <gensim.models.keyedvectors.Vocab at 0x1d053a8ab88>,
#  'sweetness': <gensim.models.keyedvectors.Vocab at 0x1d053a8abc8>,
#  'off': <gensim.models.keyedvectors.Vocab at 0x1d053a8ac08>,
#  'Alicante': <gensim.models.keyedvectors.Vocab at 0x1d053a8ac48>,
#  'Bouschet': <gensim.models.keyedvectors.Vocab at 0x1d053a8ac88>,
#  'dominates': <gensim.models.keyedvectors.Vocab at 0x1d053a8acc8>,
#  'firmly': <gensim.models.keyedvectors.Vocab at 0x1d053a8ad08>,
#  'hugely': <gensim.models.keyedvectors.Vocab at 0x1d053a8ad48>,
#  'Wait': <gensim.models.keyedvectors.Vocab at 0x1d053a8ad88>,
#  'different': <gensim.models.keyedvectors.Vocab at 0x1d053a8adc8>,
#  'widely': <gensim.models.keyedvectors.Vocab at 0x1d053a8ae08>,
#  'available': <gensim.models.keyedvectors.Vocab at 0x1d053a8ae48>,
#  'cuv': <gensim.models.keyedvectors.Vocab at 0x1d053a8ae88>,
#  'e': <gensim.models.keyedvectors.Vocab at 0x1d053a8aec8>,
#  'sturdy': <gensim.models.keyedvectors.Vocab at 0x1d053a8af08>,
#  'currant': <gensim.models.keyedvectors.Vocab at 0x1d053a8af48>,
#  'would': <gensim.models.keyedvectors.Vocab at 0x1d053a8af88>,
#  'ideal': <gensim.models.keyedvectors.Vocab at 0x1d053a8afc8>,
#  ...}

# %%
print(wine2vec.corpus_count)
# Out:
# 266254

# %%
wine2vec.train(sentences, total_examples=wine2vec.corpus_count, epochs=wine2vec.iter)
# Out:
# C:\Users\Threadripper\anaconda3\envs\winereviews\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `iter` (Attribute will be removed in 4.0.0, use self.epochs instead).
#   """Entry point for launching an IPython kernel.
# (22314594, 30973815)

# %%
wine2vec.most_similar('tannin')
# Out:
# C:\Users\Threadripper\anaconda3\envs\winereviews\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('tannins', 0.5339179039001465),
#  ('tannic', 0.45286205410957336),
#  ('acid', 0.4517667293548584),
#  ('laudable', 0.45031818747520447),
#  ('Structurally', 0.4196407198905945),
#  ('powering', 0.4163557291030884),
#  ('buoy', 0.41513803601264954),
#  ('pH', 0.41407719254493713),
#  ('unobtrusive', 0.4081850051879883),
#  ('cushioning', 0.40577155351638794)]

# %%
wine2vec.most_similar('bad')
# Out:
# C:\Users\Threadripper\anaconda3\envs\winereviews\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('awful', 0.5221390724182129),
#  ('horrible', 0.5130788087844849),
#  ('inappropriate', 0.5070090293884277),
#  ('se', 0.500730037689209),
#  ('overpriced', 0.5002012252807617),
#  ('terrible', 0.49675774574279785),
#  ('disaster', 0.4957996904850006),
#  ('unattractive', 0.4917920231819153),
#  ('Plus', 0.4725416302680969),
#  ('purposes', 0.4697968661785126)]

# %%
wine2vec.most_similar('oak')

# %%
wine2vec.most_similar('acidic')

# %%
wine2vec.most_similar('full')

# %%
wine2vec.most_similar('tannins')

# %%
def nearest_similarity_cosmul(start1, end1, end2):
    similarities = wine2vec.most_similar_cosmul(
        positive=[end2, start1],
        negative=[end1]
    )
    start2 = similarities[0][0]
    print("{start1} is related to {end1}, as {start2} is related to {end2}".format(**locals()))
    return start2

# %%
nearest_similarity_cosmul('oak', 'vanilla', 'cherry');

# %%
nearest_similarity_cosmul('full', 'berry', 'light');

# %%
nearest_similarity_cosmul('tannins', 'plum', 'fresh');

# %%
nearest_similarity_cosmul('full', 'bodied', 'acidic');

# %%
wine2vec.most_similar('sweetness')

# %%
wine2vec.most_similar('alcohol')

# %%
wine2vec.most_similar('aromas')

# %%
wine2vec.most_similar('gumdrop')
