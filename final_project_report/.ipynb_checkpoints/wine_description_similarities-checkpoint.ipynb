# %%
from collections import Counter
import numpy as np
import nltk
import re
import sklearn.manifold
import multiprocessing
import pandas as pd
import gensim.models.word2vec as w2v

# %%
data = pd.read_csv('winemag-data_first150k.csv')

# %%
labels = data['variety']
descriptions = data['description']

# %%
print('{}   :   {}'.format(labels.tolist()[0], descriptions.tolist()[0]))
print('{}   :   {}'.format(labels.tolist()[56], descriptions.tolist()[56]))
print('{}   :   {}'.format(labels.tolist()[93], descriptions.tolist()[93]))
# Out:
# Cabernet Sauvignon   :   This tremendous 100% varietal wine hails from Oakville and was aged over three years in oak. Juicy red-cherry fruit and a compelling hint of caramel greet the palate, framed by elegant, fine tannins and a subtle minty tone in the background. Balanced and rewarding from start to finish, it has years ahead of it to develop further nuance. Enjoy 2022–2030.
# Sauvignon Blanc   :   Delicious while also young and textured, this wine comes from biodynamically grown grapes. It has a strong sense of minerality as well as intense citrus and green fruits. It's tight at the moment and needs to round out, so drink from 2018.
# Chardonnay   :   A smoky scent and earthy, crisp-apple flavors make this medium-bodied wine a change of pace from the average butterball Chardonnay. It has welcome acidity and a nicely smooth texture.

# %%
varietal_counts = labels.value_counts()
print(varietal_counts[:50])
# Out:
# Chardonnay                       14482
# Pinot Noir                       14291
# Cabernet Sauvignon               12800
# Red Blend                        10062
# Bordeaux-style Red Blend          7347
# Sauvignon Blanc                   6320
# Syrah                             5825
# Riesling                          5524
# Merlot                            5070
# Zinfandel                         3799
# Sangiovese                        3345
# Malbec                            3208
# White Blend                       2824
# Rosé                              2817
# Tempranillo                       2556
# Nebbiolo                          2241
# Portuguese Red                    2216
# Sparkling Blend                   2004
# Shiraz                            1970
# Corvina, Rondinella, Molinara     1682
# Rhône-style Red Blend             1505
# Barbera                           1365
# Pinot Gris                        1365
# Cabernet Franc                    1363
# Sangiovese Grosso                 1346
# Pinot Grigio                      1305
# Viognier                          1263
# Bordeaux-style White Blend        1261
# Champagne Blend                   1238
# Port                              1058
# Grüner Veltliner                  1042
# Gewürztraminer                     982
# Portuguese White                   941
# Petite Sirah                       897
# Carmenère                          761
# Tempranillo Blend                  756
# Chenin Blanc                       746
# Glera                              622
# Grenache                           603
# Prosecco                           594
# Albariño                           537
# Gamay                              535
# Pinot Blanc                        470
# Nero d'Avola                       458
# Moscato                            430
# Rhône-style White Blend            409
# Garganega                          402
# Garnacha                           401
# Torrontés                          367
# Dolcetto                           358
# Name: variety, dtype: int64

# %%
corpus_raw = ""
for description in descriptions:
    corpus_raw += description

# %%
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

# %%
raw_sentences = tokenizer.tokenize(corpus_raw)

# %%
def sentence_to_wordlist(raw):
    clean = re.sub("[^a-zA-Z]"," ", raw)
    words = clean.split()
    return words

# %%
sentences = []
for raw_sentence in raw_sentences:
    if len(raw_sentence) > 0:
        sentences.append(sentence_to_wordlist(raw_sentence))

# %%
print(raw_sentences[0])
print(sentence_to_wordlist(raw_sentences[0]))
# Out:
# This tremendous 100% varietal wine hails from Oakville and was aged over three years in oak.
# ['This', 'tremendous', 'varietal', 'wine', 'hails', 'from', 'Oakville', 'and', 'was', 'aged', 'over', 'three', 'years', 'in', 'oak']

# %%
token_count = sum([len(sentence) for sentence in sentences])
print('The wine corpus contains {0:,} tokens'.format(token_count))
# Out:
# The wine corpus contains 6,194,763 tokens

# %%
num_features = 300
min_word_count = 10
num_workers = multiprocessing.cpu_count()
context_size = 10
downsampling = 1e-3
seed=1993

# %%
wine2vec = w2v.Word2Vec(
    sg=1,
    seed=seed,
    workers=num_workers,
    size=num_features,
    min_count=min_word_count,
    window=context_size,
    sample=downsampling
)

# %%
wine2vec.build_vocab(sentences)

# %%
print('Word2Vec vocabulary length:', len(wine2vec.wv.vocab))
# Out:
# Word2Vec vocabulary length: 11379

# %%
wine2vec.wv.vocab
# Out:
# {'This': <gensim.models.keyedvectors.Vocab at 0x1afb12ab788>,
#  'tremendous': <gensim.models.keyedvectors.Vocab at 0x1afb12af088>,
#  'varietal': <gensim.models.keyedvectors.Vocab at 0x1afb12b3308>,
#  'wine': <gensim.models.keyedvectors.Vocab at 0x1afb12b3388>,
#  'hails': <gensim.models.keyedvectors.Vocab at 0x1afb12b3508>,
#  'from': <gensim.models.keyedvectors.Vocab at 0x1afb12b3588>,
#  'Oakville': <gensim.models.keyedvectors.Vocab at 0x1afb12b35c8>,
#  'and': <gensim.models.keyedvectors.Vocab at 0x1afb12b3608>,
#  'was': <gensim.models.keyedvectors.Vocab at 0x1afb12b3488>,
#  'aged': <gensim.models.keyedvectors.Vocab at 0x1afb12b3548>,
#  'over': <gensim.models.keyedvectors.Vocab at 0x1afb12b3648>,
#  'three': <gensim.models.keyedvectors.Vocab at 0x1afb12b3688>,
#  'years': <gensim.models.keyedvectors.Vocab at 0x1afb12b36c8>,
#  'in': <gensim.models.keyedvectors.Vocab at 0x1afb12b3708>,
#  'oak': <gensim.models.keyedvectors.Vocab at 0x1afb12b3748>,
#  'Juicy': <gensim.models.keyedvectors.Vocab at 0x1afb12b3788>,
#  'red': <gensim.models.keyedvectors.Vocab at 0x1afb12b37c8>,
#  'cherry': <gensim.models.keyedvectors.Vocab at 0x1afb12b3808>,
#  'fruit': <gensim.models.keyedvectors.Vocab at 0x1afb12b3848>,
#  'a': <gensim.models.keyedvectors.Vocab at 0x1afb12b3888>,
#  'compelling': <gensim.models.keyedvectors.Vocab at 0x1afb12b38c8>,
#  'hint': <gensim.models.keyedvectors.Vocab at 0x1afb12b3908>,
#  'of': <gensim.models.keyedvectors.Vocab at 0x1afb12b3948>,
#  'caramel': <gensim.models.keyedvectors.Vocab at 0x1afb12b3988>,
#  'greet': <gensim.models.keyedvectors.Vocab at 0x1afb12b39c8>,
#  'the': <gensim.models.keyedvectors.Vocab at 0x1afb12b3a08>,
#  'palate': <gensim.models.keyedvectors.Vocab at 0x1afb12b3a48>,
#  'framed': <gensim.models.keyedvectors.Vocab at 0x1afb12b3a88>,
#  'by': <gensim.models.keyedvectors.Vocab at 0x1afb12b3ac8>,
#  'elegant': <gensim.models.keyedvectors.Vocab at 0x1afb12b3b08>,
#  'fine': <gensim.models.keyedvectors.Vocab at 0x1afb12b3b48>,
#  'tannins': <gensim.models.keyedvectors.Vocab at 0x1afb12b3b88>,
#  'subtle': <gensim.models.keyedvectors.Vocab at 0x1afb12b3bc8>,
#  'minty': <gensim.models.keyedvectors.Vocab at 0x1afb12b3c08>,
#  'tone': <gensim.models.keyedvectors.Vocab at 0x1afb12b3c48>,
#  'background': <gensim.models.keyedvectors.Vocab at 0x1afb12b3c88>,
#  'Balanced': <gensim.models.keyedvectors.Vocab at 0x1afb12b3cc8>,
#  'rewarding': <gensim.models.keyedvectors.Vocab at 0x1afb12b3d08>,
#  'start': <gensim.models.keyedvectors.Vocab at 0x1afb12b3d48>,
#  'to': <gensim.models.keyedvectors.Vocab at 0x1afb12b3d88>,
#  'finish': <gensim.models.keyedvectors.Vocab at 0x1afb12b3dc8>,
#  'it': <gensim.models.keyedvectors.Vocab at 0x1afb12b3e08>,
#  'has': <gensim.models.keyedvectors.Vocab at 0x1afb12b3e48>,
#  'ahead': <gensim.models.keyedvectors.Vocab at 0x1afb12b3e88>,
#  'develop': <gensim.models.keyedvectors.Vocab at 0x1afb12b3ec8>,
#  'further': <gensim.models.keyedvectors.Vocab at 0x1afb12b3f08>,
#  'nuance': <gensim.models.keyedvectors.Vocab at 0x1afb12b3f48>,
#  'Enjoy': <gensim.models.keyedvectors.Vocab at 0x1afb12b3f88>,
#  'Ripe': <gensim.models.keyedvectors.Vocab at 0x1afb12b3fc8>,
#  'aromas': <gensim.models.keyedvectors.Vocab at 0x1afb12c4048>,
#  'fig': <gensim.models.keyedvectors.Vocab at 0x1afb12c4088>,
#  'blackberry': <gensim.models.keyedvectors.Vocab at 0x1afb12c40c8>,
#  'cassis': <gensim.models.keyedvectors.Vocab at 0x1afb12c4108>,
#  'are': <gensim.models.keyedvectors.Vocab at 0x1afb12c4148>,
#  'softened': <gensim.models.keyedvectors.Vocab at 0x1afb12c4188>,
#  'sweetened': <gensim.models.keyedvectors.Vocab at 0x1afb12c41c8>,
#  'oaky': <gensim.models.keyedvectors.Vocab at 0x1afb12c4208>,
#  'chocolate': <gensim.models.keyedvectors.Vocab at 0x1afb12c4248>,
#  'vanilla': <gensim.models.keyedvectors.Vocab at 0x1afb12c4288>,
#  'is': <gensim.models.keyedvectors.Vocab at 0x1afb12c42c8>,
#  'full': <gensim.models.keyedvectors.Vocab at 0x1afb12c4308>,
#  'layered': <gensim.models.keyedvectors.Vocab at 0x1afb12c4348>,
#  'intense': <gensim.models.keyedvectors.Vocab at 0x1afb12c4388>,
#  'cushioned': <gensim.models.keyedvectors.Vocab at 0x1afb12c43c8>,
#  'on': <gensim.models.keyedvectors.Vocab at 0x1afb12c4408>,
#  'with': <gensim.models.keyedvectors.Vocab at 0x1afb12afe88>,
#  'rich': <gensim.models.keyedvectors.Vocab at 0x1afb12aff48>,
#  'flavors': <gensim.models.keyedvectors.Vocab at 0x1afb12af288>,
#  'chocolaty': <gensim.models.keyedvectors.Vocab at 0x1afb12adc88>,
#  'black': <gensim.models.keyedvectors.Vocab at 0x1afb12ad888>,
#  'fruits': <gensim.models.keyedvectors.Vocab at 0x1afb12adb08>,
#  'baking': <gensim.models.keyedvectors.Vocab at 0x1afb12adcc8>,
#  'spices': <gensim.models.keyedvectors.Vocab at 0x1afb12adc48>,
#  'A': <gensim.models.keyedvectors.Vocab at 0x1afb12adbc8>,
#  'toasty': <gensim.models.keyedvectors.Vocab at 0x1afb12adb88>,
#  'heady': <gensim.models.keyedvectors.Vocab at 0x1afb12ad948>,
#  'but': <gensim.models.keyedvectors.Vocab at 0x1afb12adc08>,
#  'ideally': <gensim.models.keyedvectors.Vocab at 0x1afb12ad608>,
#  'balanced': <gensim.models.keyedvectors.Vocab at 0x1afb12adb48>,
#  'Drink': <gensim.models.keyedvectors.Vocab at 0x1afb12ad9c8>,
#  'through': <gensim.models.keyedvectors.Vocab at 0x1afb12adac8>,
#  'honors': <gensim.models.keyedvectors.Vocab at 0x1afb12ada08>,
#  'memory': <gensim.models.keyedvectors.Vocab at 0x1afb12ada88>,
#  'once': <gensim.models.keyedvectors.Vocab at 0x1afb12ad908>,
#  'made': <gensim.models.keyedvectors.Vocab at 0x1afb12ad348>,
#  'his': <gensim.models.keyedvectors.Vocab at 0x1afb12ad2c8>,
#  'mother': <gensim.models.keyedvectors.Vocab at 0x1afb12ad8c8>,
#  'this': <gensim.models.keyedvectors.Vocab at 0x1afb12ad508>,
#  'tremendously': <gensim.models.keyedvectors.Vocab at 0x1afb12ad088>,
#  'delicious': <gensim.models.keyedvectors.Vocab at 0x1afb12ad148>,
#  'complex': <gensim.models.keyedvectors.Vocab at 0x1afb12ad048>,
#  'botrytised': <gensim.models.keyedvectors.Vocab at 0x1afb12ad3c8>,
#  'white': <gensim.models.keyedvectors.Vocab at 0x1afb12abf08>,
#  'Dark': <gensim.models.keyedvectors.Vocab at 0x1afb12ab488>,
#  'gold': <gensim.models.keyedvectors.Vocab at 0x1afb12abfc8>,
#  'color': <gensim.models.keyedvectors.Vocab at 0x1afb12abec8>,
#  'layers': <gensim.models.keyedvectors.Vocab at 0x1afb12ab148>,
#  'toasted': <gensim.models.keyedvectors.Vocab at 0x1afb12abf88>,
#  'hazelnut': <gensim.models.keyedvectors.Vocab at 0x1afb12abf48>,
#  'pear': <gensim.models.keyedvectors.Vocab at 0x1afb12ab6c8>,
#  'compote': <gensim.models.keyedvectors.Vocab at 0x1afb12aba08>,
#  'orange': <gensim.models.keyedvectors.Vocab at 0x1afb12ab7c8>,
#  'peel': <gensim.models.keyedvectors.Vocab at 0x1afb12ab808>,
#  'succulence': <gensim.models.keyedvectors.Vocab at 0x1afb12abe48>,
#  'its': <gensim.models.keyedvectors.Vocab at 0x1afb12ab8c8>,
#  'g': <gensim.models.keyedvectors.Vocab at 0x1afb12abc08>,
#  'L': <gensim.models.keyedvectors.Vocab at 0x1afb12ab088>,
#  'residual': <gensim.models.keyedvectors.Vocab at 0x1afb12ab5c8>,
#  'sugar': <gensim.models.keyedvectors.Vocab at 0x1afb12ab3c8>,
#  'spent': <gensim.models.keyedvectors.Vocab at 0x1afb12ab1c8>,
#  'months': <gensim.models.keyedvectors.Vocab at 0x1afb12ab608>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x1afb12ab048>,
#  'French': <gensim.models.keyedvectors.Vocab at 0x1afb12ab0c8>,
#  'incorporates': <gensim.models.keyedvectors.Vocab at 0x1afb12ab108>,
#  'Ponzi': <gensim.models.keyedvectors.Vocab at 0x1afb12ab548>,
#  's': <gensim.models.keyedvectors.Vocab at 0x1afb12a9e08>,
#  'vineyards': <gensim.models.keyedvectors.Vocab at 0x1afb12a9f48>,
#  'among': <gensim.models.keyedvectors.Vocab at 0x1afb12a9e48>,
#  'others': <gensim.models.keyedvectors.Vocab at 0x1afb12a9fc8>,
#  'Aromatic': <gensim.models.keyedvectors.Vocab at 0x1afb12a9dc8>,
#  'dense': <gensim.models.keyedvectors.Vocab at 0x1afb12a9d48>,
#  'deftly': <gensim.models.keyedvectors.Vocab at 0x1afb12a9f88>,
#  'blends': <gensim.models.keyedvectors.Vocab at 0x1afb12a9d08>,
#  'toast': <gensim.models.keyedvectors.Vocab at 0x1afb12a9ec8>,
#  'cigar': <gensim.models.keyedvectors.Vocab at 0x1afb12a90c8>,
#  'box': <gensim.models.keyedvectors.Vocab at 0x1afb12a9088>,
#  'coffee': <gensim.models.keyedvectors.Vocab at 0x1afb12a9048>,
#  'graphite': <gensim.models.keyedvectors.Vocab at 0x1afb12a8ec8>,
#  'Tannins': <gensim.models.keyedvectors.Vocab at 0x1afb12a8fc8>,
#  'polished': <gensim.models.keyedvectors.Vocab at 0x1afb12a8f88>,
#  'sheen': <gensim.models.keyedvectors.Vocab at 0x1afb12a8f48>,
#  'frame': <gensim.models.keyedvectors.Vocab at 0x1afb12a8f08>,
#  'loaded': <gensim.models.keyedvectors.Vocab at 0x1afb12a8e48>,
#  'dark': <gensim.models.keyedvectors.Vocab at 0x1afb12a8e08>,
#  'espresso': <gensim.models.keyedvectors.Vocab at 0x1afb12a8dc8>,
#  'now': <gensim.models.keyedvectors.Vocab at 0x1afb12a8d88>,
#  'top': <gensim.models.keyedvectors.Vocab at 0x1af8e539ec8>,
#  'La': <gensim.models.keyedvectors.Vocab at 0x1af8e539f08>,
#  'B': <gensim.models.keyedvectors.Vocab at 0x1af8e539788>,
#  'named': <gensim.models.keyedvectors.Vocab at 0x1af8e5399c8>,
#  'after': <gensim.models.keyedvectors.Vocab at 0x1af8e539608>,
#  'highest': <gensim.models.keyedvectors.Vocab at 0x1af8e5398c8>,
#  'point': <gensim.models.keyedvectors.Vocab at 0x1af8e539948>,
#  'vineyard': <gensim.models.keyedvectors.Vocab at 0x1af8e539988>,
#  'at': <gensim.models.keyedvectors.Vocab at 0x1af8e539908>,
#  'feet': <gensim.models.keyedvectors.Vocab at 0x1af8e539688>,
#  'It': <gensim.models.keyedvectors.Vocab at 0x1af8e5397c8>,
#  'structure': <gensim.models.keyedvectors.Vocab at 0x1af8e539588>,
#  'density': <gensim.models.keyedvectors.Vocab at 0x1af8e539808>,
#  'considerable': <gensim.models.keyedvectors.Vocab at 0x1af8e539208>,
#  'acidity': <gensim.models.keyedvectors.Vocab at 0x1af8e5396c8>,
#  'that': <gensim.models.keyedvectors.Vocab at 0x1af8e539e88>,
#  'still': <gensim.models.keyedvectors.Vocab at 0x1af8e539bc8>,
#  'calming': <gensim.models.keyedvectors.Vocab at 0x1af8e539f48>,
#  'down': <gensim.models.keyedvectors.Vocab at 0x1af8e539c08>,
#  'With': <gensim.models.keyedvectors.Vocab at 0x1afb12c4448>,
#  'wood': <gensim.models.keyedvectors.Vocab at 0x1afb12c4488>,
#  'developing': <gensim.models.keyedvectors.Vocab at 0x1afb12c44c8>,
#  'an': <gensim.models.keyedvectors.Vocab at 0x1afb12c4508>,
#  'extra': <gensim.models.keyedvectors.Vocab at 0x1afb12c4548>,
#  'richness': <gensim.models.keyedvectors.Vocab at 0x1afb12c4588>,
#  'concentration': <gensim.models.keyedvectors.Vocab at 0x1afb12c45c8>,
#  'Produced': <gensim.models.keyedvectors.Vocab at 0x1afb12c4608>,
#  'family': <gensim.models.keyedvectors.Vocab at 0x1afb12c4648>,
#  'formerly': <gensim.models.keyedvectors.Vocab at 0x1afb12c4688>,
#  'Ch': <gensim.models.keyedvectors.Vocab at 0x1afb12c46c8>,
#  'teau': <gensim.models.keyedvectors.Vocab at 0x1afb12c4708>,
#  'Giscours': <gensim.models.keyedvectors.Vocab at 0x1afb12c4748>,
#  'Margaux': <gensim.models.keyedvectors.Vocab at 0x1afb12c4788>,
#  'for': <gensim.models.keyedvectors.Vocab at 0x1afb12c47c8>,
#  'aging': <gensim.models.keyedvectors.Vocab at 0x1afb12c4808>,
#  'Deep': <gensim.models.keyedvectors.Vocab at 0x1afb12c4848>,
#  'pure': <gensim.models.keyedvectors.Vocab at 0x1afb12c4888>,
#  'opening': <gensim.models.keyedvectors.Vocab at 0x1afb12c48c8>,
#  'bell': <gensim.models.keyedvectors.Vocab at 0x1afb12c4908>,
#  'Toro': <gensim.models.keyedvectors.Vocab at 0x1afb12c4948>,
#  'winner': <gensim.models.keyedvectors.Vocab at 0x1afb12c4988>,
#  'Aromas': <gensim.models.keyedvectors.Vocab at 0x1afb12c49c8>,
#  'ripe': <gensim.models.keyedvectors.Vocab at 0x1afb12c4a08>,
#  'cool': <gensim.models.keyedvectors.Vocab at 0x1afb12c4a48>,
#  'moderately': <gensim.models.keyedvectors.Vocab at 0x1afb12c4a88>,
#  'oaked': <gensim.models.keyedvectors.Vocab at 0x1afb12c4ac8>,
#  'feels': <gensim.models.keyedvectors.Vocab at 0x1afb12c4b08>,
#  'massive': <gensim.models.keyedvectors.Vocab at 0x1afb12c4b48>,
#  'Flavors': <gensim.models.keyedvectors.Vocab at 0x1afb12c4b88>,
#  'mocha': <gensim.models.keyedvectors.Vocab at 0x1afb12c4bc8>,
#  'spicy': <gensim.models.keyedvectors.Vocab at 0x1afb12c4c08>,
#  'smooth': <gensim.models.keyedvectors.Vocab at 0x1afb12c4c48>,
#  'exemplary': <gensim.models.keyedvectors.Vocab at 0x1afb12c4c88>,
#  'Slightly': <gensim.models.keyedvectors.Vocab at 0x1afb12c4cc8>,
#  'gritty': <gensim.models.keyedvectors.Vocab at 0x1afb12c4d08>,
#  'include': <gensim.models.keyedvectors.Vocab at 0x1afb12c4d48>,
#  'sweet': <gensim.models.keyedvectors.Vocab at 0x1afb12c4d88>,
#  'note': <gensim.models.keyedvectors.Vocab at 0x1afb12c4dc8>,
#  'pastry': <gensim.models.keyedvectors.Vocab at 0x1afb12c4e08>,
#  'along': <gensim.models.keyedvectors.Vocab at 0x1afb12c4e48>,
#  'prune': <gensim.models.keyedvectors.Vocab at 0x1afb12c4e88>,
#  'wall': <gensim.models.keyedvectors.Vocab at 0x1afb12c4ec8>,
#  'saturation': <gensim.models.keyedvectors.Vocab at 0x1afb12c4f08>,
#  'ensures': <gensim.models.keyedvectors.Vocab at 0x1afb12c4f48>,
#  'all': <gensim.models.keyedvectors.Vocab at 0x1afb12c4f88>,
#  'corners': <gensim.models.keyedvectors.Vocab at 0x1afb12c4fc8>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x1afb12ca048>,
#  'mouth': <gensim.models.keyedvectors.Vocab at 0x1afb12ca088>,
#  'covered': <gensim.models.keyedvectors.Vocab at 0x1afb12ca0c8>,
#  'highly': <gensim.models.keyedvectors.Vocab at 0x1afb12ca108>,
#  'impressive': <gensim.models.keyedvectors.Vocab at 0x1afb12ca148>,
#  'expressive': <gensim.models.keyedvectors.Vocab at 0x1afb12ca188>,
#  'while': <gensim.models.keyedvectors.Vocab at 0x1afb12ca1c8>,
#  'settles': <gensim.models.keyedvectors.Vocab at 0x1afb12ca208>,
#  'nicely': <gensim.models.keyedvectors.Vocab at 0x1afb12ca248>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x1afb12ca288>,
#  'Lush': <gensim.models.keyedvectors.Vocab at 0x1afb12ca2c8>,
#  'cedary': <gensim.models.keyedvectors.Vocab at 0x1afb12ca308>,
#  'luxe': <gensim.models.keyedvectors.Vocab at 0x1afb12ca348>,
#  'offer': <gensim.models.keyedvectors.Vocab at 0x1afb12ca388>,
#  'notes': <gensim.models.keyedvectors.Vocab at 0x1afb12ca3c8>,
#  'marzipan': <gensim.models.keyedvectors.Vocab at 0x1afb12ca408>,
#  'bruiser': <gensim.models.keyedvectors.Vocab at 0x1afb12ca448>,
#  'tannic': <gensim.models.keyedvectors.Vocab at 0x1afb12ca488>,
#  'lush': <gensim.models.keyedvectors.Vocab at 0x1afb12ca4c8>,
#  'friendly': <gensim.models.keyedvectors.Vocab at 0x1afb12ca508>,
#  'Chocolate': <gensim.models.keyedvectors.Vocab at 0x1afb12ca548>,
#  'key': <gensim.models.keyedvectors.Vocab at 0x1afb12ca588>,
#  'flavor': <gensim.models.keyedvectors.Vocab at 0x1afb12ca5c8>,
#  'baked': <gensim.models.keyedvectors.Vocab at 0x1afb12ca608>,
#  'berry': <gensim.models.keyedvectors.Vocab at 0x1afb12ca648>,
#  'hardly': <gensim.models.keyedvectors.Vocab at 0x1afb12ca688>,
#  'On': <gensim.models.keyedvectors.Vocab at 0x1afb12ca6c8>,
#  'deep': <gensim.models.keyedvectors.Vocab at 0x1afb12ca708>,
#  'as': <gensim.models.keyedvectors.Vocab at 0x1afb12ca748>,
#  'sea': <gensim.models.keyedvectors.Vocab at 0x1afb12ca788>,
#  'saturated': <gensim.models.keyedvectors.Vocab at 0x1afb12ca7c8>,
#  'colored': <gensim.models.keyedvectors.Vocab at 0x1afb12ca808>,
#  're': <gensim.models.keyedvectors.Vocab at 0x1afb12ca848>,
#  'bottled': <gensim.models.keyedvectors.Vocab at 0x1afb12ca888>,
#  'You': <gensim.models.keyedvectors.Vocab at 0x1afb12ca8c8>,
#  'll': <gensim.models.keyedvectors.Vocab at 0x1afb12ca908>,
#  'find': <gensim.models.keyedvectors.Vocab at 0x1afb12ca948>,
#  'striking': <gensim.models.keyedvectors.Vocab at 0x1afb12ca988>,
#  'minerality': <gensim.models.keyedvectors.Vocab at 0x1afb12ca9c8>,
#  'underscoring': <gensim.models.keyedvectors.Vocab at 0x1afb12caa08>,
#  'chunky': <gensim.models.keyedvectors.Vocab at 0x1afb12caa48>,
#  'Accents': <gensim.models.keyedvectors.Vocab at 0x1afb12caa88>,
#  'citrus': <gensim.models.keyedvectors.Vocab at 0x1afb12caac8>,
#  'exceptional': <gensim.models.keyedvectors.Vocab at 0x1afb12cab08>,
#  'midpalate': <gensim.models.keyedvectors.Vocab at 0x1afb12cab48>,
#  'cellar': <gensim.models.keyedvectors.Vocab at 0x1afb12cab88>,
#  'though': <gensim.models.keyedvectors.Vocab at 0x1afb12cabc8>,
#  'already': <gensim.models.keyedvectors.Vocab at 0x1afb12cac08>,
#  'quite': <gensim.models.keyedvectors.Vocab at 0x1afb12cac48>,
#  'enjoyable': <gensim.models.keyedvectors.Vocab at 0x1afb12cac88>,
#  'The': <gensim.models.keyedvectors.Vocab at 0x1afb12cacc8>,
#  'producer': <gensim.models.keyedvectors.Vocab at 0x1afb12cad08>,
#  'sources': <gensim.models.keyedvectors.Vocab at 0x1afb12cad48>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x1afb12cad88>,
#  'blocks': <gensim.models.keyedvectors.Vocab at 0x1afb12cadc8>,
#  'high': <gensim.models.keyedvectors.Vocab at 0x1afb12cae08>,
#  'elevation': <gensim.models.keyedvectors.Vocab at 0x1afb12cae48>,
#  'which': <gensim.models.keyedvectors.Vocab at 0x1afb12cae88>,
#  'contributes': <gensim.models.keyedvectors.Vocab at 0x1afb12caec8>,
#  'bright': <gensim.models.keyedvectors.Vocab at 0x1afb12caf08>,
#  'Crunchy': <gensim.models.keyedvectors.Vocab at 0x1afb12caf48>,
#  'cranberry': <gensim.models.keyedvectors.Vocab at 0x1afb12caf88>,
#  'pomegranate': <gensim.models.keyedvectors.Vocab at 0x1afb12cafc8>,
#  'surround': <gensim.models.keyedvectors.Vocab at 0x1afb12cc048>,
#  'silky': <gensim.models.keyedvectors.Vocab at 0x1afb12cc088>,
#  'succulent': <gensim.models.keyedvectors.Vocab at 0x1afb12cc0c8>,
#  'texture': <gensim.models.keyedvectors.Vocab at 0x1afb12cc108>,
#  'present': <gensim.models.keyedvectors.Vocab at 0x1afb12cc148>,
#  'fleshy': <gensim.models.keyedvectors.Vocab at 0x1afb12cc188>,
#  'That': <gensim.models.keyedvectors.Vocab at 0x1afb12cc1c8>,
#  'delicately': <gensim.models.keyedvectors.Vocab at 0x1afb12cc208>,
#  'length': <gensim.models.keyedvectors.Vocab at 0x1afb12cc248>,
#  'Elegance': <gensim.models.keyedvectors.Vocab at 0x1afb12cc288>,
#  'complexity': <gensim.models.keyedvectors.Vocab at 0x1afb12cc2c8>,
#  'come': <gensim.models.keyedvectors.Vocab at 0x1afb12cc308>,
#  'together': <gensim.models.keyedvectors.Vocab at 0x1afb12cc348>,
#  'drop': <gensim.models.keyedvectors.Vocab at 0x1afb12cc388>,
#  'dead': <gensim.models.keyedvectors.Vocab at 0x1afb12cc3c8>,
#  'gorgeous': <gensim.models.keyedvectors.Vocab at 0x1afb12cc408>,
#  'ranks': <gensim.models.keyedvectors.Vocab at 0x1afb12cc448>,
#  'Italy': <gensim.models.keyedvectors.Vocab at 0x1afb12cc488>,
#  'greatest': <gensim.models.keyedvectors.Vocab at 0x1afb12cc4c8>,
#  'whites': <gensim.models.keyedvectors.Vocab at 0x1afb12cc508>,
#  'opens': <gensim.models.keyedvectors.Vocab at 0x1afb12cc548>,
#  'sublime': <gensim.models.keyedvectors.Vocab at 0x1afb12cc588>,
#  'yellow': <gensim.models.keyedvectors.Vocab at 0x1afb12cc5c8>,
#  'spring': <gensim.models.keyedvectors.Vocab at 0x1afb12cc608>,
#  'flower': <gensim.models.keyedvectors.Vocab at 0x1afb12cc648>,
#  'aromatic': <gensim.models.keyedvectors.Vocab at 0x1afb12cc688>,
#  'herb': <gensim.models.keyedvectors.Vocab at 0x1afb12cc6c8>,
#  'orchard': <gensim.models.keyedvectors.Vocab at 0x1afb12cc708>,
#  'scents': <gensim.models.keyedvectors.Vocab at 0x1afb12cc748>,
#  'creamy': <gensim.models.keyedvectors.Vocab at 0x1afb12cc788>,
#  'seamlessly': <gensim.models.keyedvectors.Vocab at 0x1afb12cc7c8>,
#  'combines': <gensim.models.keyedvectors.Vocab at 0x1afb12cc808>,
#  'juicy': <gensim.models.keyedvectors.Vocab at 0x1afb12cc848>,
#  'peach': <gensim.models.keyedvectors.Vocab at 0x1afb12cc888>,
#  'almond': <gensim.models.keyedvectors.Vocab at 0x1afb12cc8c8>,
#  'savory': <gensim.models.keyedvectors.Vocab at 0x1afb12cc908>,
#  'mineral': <gensim.models.keyedvectors.Vocab at 0x1afb12cc948>,
#  'grace': <gensim.models.keyedvectors.Vocab at 0x1afb12cc988>,
#  'lingering': <gensim.models.keyedvectors.Vocab at 0x1afb12cc9c8>,
#  'From': <gensim.models.keyedvectors.Vocab at 0x1afb12cca08>,
#  'year': <gensim.models.keyedvectors.Vocab at 0x1afb12cca48>,
#  'old': <gensim.models.keyedvectors.Vocab at 0x1afb12cca88>,
#  'vines': <gensim.models.keyedvectors.Vocab at 0x1afb12ccac8>,
#  'supple': <gensim.models.keyedvectors.Vocab at 0x1afb12ccb08>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x1afb12ccb48>,
#  'effort': <gensim.models.keyedvectors.Vocab at 0x1afb12ccb88>,
#  'breakfast': <gensim.models.keyedvectors.Vocab at 0x1afb12ccbc8>,
#  'tea': <gensim.models.keyedvectors.Vocab at 0x1afb12ccc08>,
#  'Superbly': <gensim.models.keyedvectors.Vocab at 0x1afb12ccc48>,
#  'integrated': <gensim.models.keyedvectors.Vocab at 0x1afb12ccc88>,
#  'even': <gensim.models.keyedvectors.Vocab at 0x1afb12cccc8>,
#  'early': <gensim.models.keyedvectors.Vocab at 0x1afb12ccd08>,
#  'stage': <gensim.models.keyedvectors.Vocab at 0x1afb12ccd48>,
#  'seems': <gensim.models.keyedvectors.Vocab at 0x1afb12ccd88>,
#  'destined': <gensim.models.keyedvectors.Vocab at 0x1afb12ccdc8>,
#  'life': <gensim.models.keyedvectors.Vocab at 0x1afb12cce08>,
#  'standout': <gensim.models.keyedvectors.Vocab at 0x1afb12cce48>,
#  'terrific': <gensim.models.keyedvectors.Vocab at 0x1afb12cce88>,
#  'lineup': <gensim.models.keyedvectors.Vocab at 0x1afb12ccec8>,
#  'releases': <gensim.models.keyedvectors.Vocab at 0x1afb12ccf08>,
#  'Green': <gensim.models.keyedvectors.Vocab at 0x1afb12ccf48>,
#  'burst': <gensim.models.keyedvectors.Vocab at 0x1afb12ccf88>,
#  'cola': <gensim.models.keyedvectors.Vocab at 0x1afb12ccfc8>,
#  'tobacco': <gensim.models.keyedvectors.Vocab at 0x1afb12cf048>,
#  'accents': <gensim.models.keyedvectors.Vocab at 0x1afb12cf088>,
#  'continues': <gensim.models.keyedvectors.Vocab at 0x1afb12cf0c8>,
#  'detailed': <gensim.models.keyedvectors.Vocab at 0x1afb12cf108>,
#  'oranges': <gensim.models.keyedvectors.Vocab at 0x1afb12cf148>,
#  'milk': <gensim.models.keyedvectors.Vocab at 0x1afb12cf188>,
#  'threaded': <gensim.models.keyedvectors.Vocab at 0x1afb12cf1c8>,
#  'peak': <gensim.models.keyedvectors.Vocab at 0x1afb12cf208>,
#  'condition': <gensim.models.keyedvectors.Vocab at 0x1afb12cf248>,
#  'secondary': <gensim.models.keyedvectors.Vocab at 0x1afb12cf288>,
#  'dominate': <gensim.models.keyedvectors.Vocab at 0x1afb12cf2c8>,
#  'leather': <gensim.models.keyedvectors.Vocab at 0x1afb12cf308>,
#  'textured': <gensim.models.keyedvectors.Vocab at 0x1afb12cf348>,
#  'there': <gensim.models.keyedvectors.Vocab at 0x1afb12cf388>,
#  'dried': <gensim.models.keyedvectors.Vocab at 0x1afb12cf3c8>,
#  'berries': <gensim.models.keyedvectors.Vocab at 0x1afb12cf408>,
#  'hints': <gensim.models.keyedvectors.Vocab at 0x1afb12cf448>,
#  'plum': <gensim.models.keyedvectors.Vocab at 0x1afb12cf488>,
#  'skins': <gensim.models.keyedvectors.Vocab at 0x1afb12cf4c8>,
#  'major': <gensim.models.keyedvectors.Vocab at 0x1afb12cf508>,
#  'right': <gensim.models.keyedvectors.Vocab at 0x1afb12cf548>,
#  'drinking': <gensim.models.keyedvectors.Vocab at 0x1afb12cf588>,
#  'both': <gensim.models.keyedvectors.Vocab at 0x1afb12cf5c8>,
#  'mature': <gensim.models.keyedvectors.Vocab at 0x1afb12cf608>,
#  'balance': <gensim.models.keyedvectors.Vocab at 0x1afb12cf648>,
#  'sophisticated': <gensim.models.keyedvectors.Vocab at 0x1afb12cf688>,
#  'mix': <gensim.models.keyedvectors.Vocab at 0x1afb12cf6c8>,
#  'acid': <gensim.models.keyedvectors.Vocab at 0x1afb12cf708>,
#  'tart': <gensim.models.keyedvectors.Vocab at 0x1afb12cf748>,
#  'seductive': <gensim.models.keyedvectors.Vocab at 0x1afb12cf788>,
#  'pleases': <gensim.models.keyedvectors.Vocab at 0x1afb12cf7c8>,
#  'Supple': <gensim.models.keyedvectors.Vocab at 0x1afb12cf808>,
#  'got': <gensim.models.keyedvectors.Vocab at 0x1afb12cf848>,
#  'strawberry': <gensim.models.keyedvectors.Vocab at 0x1afb12cf888>,
#  'blueberry': <gensim.models.keyedvectors.Vocab at 0x1afb12cf8c8>,
#  'touch': <gensim.models.keyedvectors.Vocab at 0x1afb12cf908>,
#  'underlying': <gensim.models.keyedvectors.Vocab at 0x1afb12cf948>,
#  'streak': <gensim.models.keyedvectors.Vocab at 0x1afb12cf988>,
#  'All': <gensim.models.keyedvectors.Vocab at 0x1afb12cf9c8>,
#  'these': <gensim.models.keyedvectors.Vocab at 0x1afb12cfa08>,
#  'elements': <gensim.models.keyedvectors.Vocab at 0x1afb12cfa48>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x1afb12cfa88>,
#  'proportion': <gensim.models.keyedvectors.Vocab at 0x1afb12cfac8>,
#  'appealing': <gensim.models.keyedvectors.Vocab at 0x1afb12cfb08>,
#  'give': <gensim.models.keyedvectors.Vocab at 0x1afb12cfb48>,
#  'another': <gensim.models.keyedvectors.Vocab at 0x1afb12cfb88>,
#  'decade': <gensim.models.keyedvectors.Vocab at 0x1afb12cfbc8>,
#  'enjoyment': <gensim.models.keyedvectors.Vocab at 0x1afb12cfc08>,
#  'First': <gensim.models.keyedvectors.Vocab at 0x1afb12cfc48>,
#  'luscious': <gensim.models.keyedvectors.Vocab at 0x1afb12cfc88>,
#  'Chardonnay': <gensim.models.keyedvectors.Vocab at 0x1afb12cfcc8>,
#  'about': <gensim.models.keyedvectors.Vocab at 0x1afb12cfd08>,
#  'core': <gensim.models.keyedvectors.Vocab at 0x1afb12cfd48>,
#  'butterscotch': <gensim.models.keyedvectors.Vocab at 0x1afb12cfd88>,
#  'seemingly': <gensim.models.keyedvectors.Vocab at 0x1afb12cfdc8>,
#  'endless': <gensim.models.keyedvectors.Vocab at 0x1afb12cfe08>,
#  'biodynamic': <gensim.models.keyedvectors.Vocab at 0x1afb12cfe48>,
#  'farming': <gensim.models.keyedvectors.Vocab at 0x1afb12cfe88>,
#  'can': <gensim.models.keyedvectors.Vocab at 0x1afb12cfec8>,
#  'bring': <gensim.models.keyedvectors.Vocab at 0x1afb12cff08>,
#  'spends': <gensim.models.keyedvectors.Vocab at 0x1afb12cff48>,
#  'lees': <gensim.models.keyedvectors.Vocab at 0x1afb12cff88>,
#  'prior': <gensim.models.keyedvectors.Vocab at 0x1afb12cffc8>,
#  'bottling': <gensim.models.keyedvectors.Vocab at 0x1afb12d3048>,
#  'blockbuster': <gensim.models.keyedvectors.Vocab at 0x1afb12d3088>,
#  'powerhouse': <gensim.models.keyedvectors.Vocab at 0x1afb12d30c8>,
#  'suggests': <gensim.models.keyedvectors.Vocab at 0x1afb12d3108>,
#  'pie': <gensim.models.keyedvectors.Vocab at 0x1afb12d3148>,
#  'glass': <gensim.models.keyedvectors.Vocab at 0x1afb12d3188>,
#  'seductively': <gensim.models.keyedvectors.Vocab at 0x1afb12d31c8>,
#  'offering': <gensim.models.keyedvectors.Vocab at 0x1afb12d3208>,
#  'cedar': <gensim.models.keyedvectors.Vocab at 0x1afb12d3248>,
#  'peppercorn': <gensim.models.keyedvectors.Vocab at 0x1afb12d3288>,
#  'peppery': <gensim.models.keyedvectors.Vocab at 0x1afb12d32c8>,
#  'seasonings': <gensim.models.keyedvectors.Vocab at 0x1afb12d3308>,
#  'amidst': <gensim.models.keyedvectors.Vocab at 0x1afb12d3348>,
#  'finishes': <gensim.models.keyedvectors.Vocab at 0x1afb12d3388>,
#  'finesse': <gensim.models.keyedvectors.Vocab at 0x1afb12d33c8>,
#  'spice': <gensim.models.keyedvectors.Vocab at 0x1afb12d3408>,
#  'Nicely': <gensim.models.keyedvectors.Vocab at 0x1afb12d3448>,
#  'licorice': <gensim.models.keyedvectors.Vocab at 0x1afb12d3488>,
#  'charred': <gensim.models.keyedvectors.Vocab at 0x1afb12d34c8>,
#  'sultry': <gensim.models.keyedvectors.Vocab at 0x1afb12d3508>,
#  'outstanding': <gensim.models.keyedvectors.Vocab at 0x1afb12d3548>,
#  'excellent': <gensim.models.keyedvectors.Vocab at 0x1afb12d3588>,
#  'Forward': <gensim.models.keyedvectors.Vocab at 0x1afb12d35c8>,
#  'barrel': <gensim.models.keyedvectors.Vocab at 0x1afb12d3608>,
#  'adorn': <gensim.models.keyedvectors.Vocab at 0x1afb12d3648>,
#  'raspberry': <gensim.models.keyedvectors.Vocab at 0x1afb12d3688>,
#  'runs': <gensim.models.keyedvectors.Vocab at 0x1afb12d36c8>,
#  'tastes': <gensim.models.keyedvectors.Vocab at 0x1afb12d3708>,
#  'vaguely': <gensim.models.keyedvectors.Vocab at 0x1afb12d3748>,
#  'velvety': <gensim.models.keyedvectors.Vocab at 0x1afb12d3788>,
#  'notch': <gensim.models.keyedvectors.Vocab at 0x1afb12d37c8>,
#  'Tempranillo': <gensim.models.keyedvectors.Vocab at 0x1afb12d3808>,
#  'Coming': <gensim.models.keyedvectors.Vocab at 0x1afb12d3848>,
#  'seven': <gensim.models.keyedvectors.Vocab at 0x1afb12d3888>,
#  'acre': <gensim.models.keyedvectors.Vocab at 0x1afb12d38c8>,
#  'property': <gensim.models.keyedvectors.Vocab at 0x1afb12d3908>,
#  'magnificent': <gensim.models.keyedvectors.Vocab at 0x1afb12d3948>,
#  'Powered': <gensim.models.keyedvectors.Vocab at 0x1afb12d3988>,
#  'darkly': <gensim.models.keyedvectors.Vocab at 0x1afb12d39c8>,
#  'great': <gensim.models.keyedvectors.Vocab at 0x1afb12d3a08>,
#  'As': <gensim.models.keyedvectors.Vocab at 0x1afb12d3a48>,
#  'sign': <gensim.models.keyedvectors.Vocab at 0x1afb12d3a88>,
#  'pedigree': <gensim.models.keyedvectors.Vocab at 0x1afb12d3ac8>,
#  'also': <gensim.models.keyedvectors.Vocab at 0x1afb12d3b08>,
#  'elegance': <gensim.models.keyedvectors.Vocab at 0x1afb12d3b48>,
#  'here': <gensim.models.keyedvectors.Vocab at 0x1afb12d3b88>,
#  'restraint': <gensim.models.keyedvectors.Vocab at 0x1afb12d3bc8>,
#  'makes': <gensim.models.keyedvectors.Vocab at 0x1afb12d3c08>,
#  'term': <gensim.models.keyedvectors.Vocab at 0x1afb12d3c48>,
#  'fresh': <gensim.models.keyedvectors.Vocab at 0x1afb12d3c88>,
#  'lively': <gensim.models.keyedvectors.Vocab at 0x1afb12d3cc8>,
#  'medium': <gensim.models.keyedvectors.Vocab at 0x1afb12d3d08>,
#  'bodied': <gensim.models.keyedvectors.Vocab at 0x1afb12d3d48>,
#  'beautifully': <gensim.models.keyedvectors.Vocab at 0x1afb12d3d88>,
#  'crafted': <gensim.models.keyedvectors.Vocab at 0x1afb12d3dc8>,
#  'blossom': <gensim.models.keyedvectors.Vocab at 0x1afb12d3e08>,
#  'tangy': <gensim.models.keyedvectors.Vocab at 0x1afb12d3e48>,
#  'Layered': <gensim.models.keyedvectors.Vocab at 0x1afb12d3e88>,
#  'offers': <gensim.models.keyedvectors.Vocab at 0x1afb12d3ec8>,
#  'crisp': <gensim.models.keyedvectors.Vocab at 0x1afb12d3f08>,
#  'ready': <gensim.models.keyedvectors.Vocab at 0x1afb12d3f48>,
#  'table': <gensim.models.keyedvectors.Vocab at 0x1afb12d3f88>,
#  'or': <gensim.models.keyedvectors.Vocab at 0x1afb12d3fc8>,
#  'stellar': <gensim.models.keyedvectors.Vocab at 0x1afb12d7048>,
#  'ros': <gensim.models.keyedvectors.Vocab at 0x1afb12d7088>,
#  'rare': <gensim.models.keyedvectors.Vocab at 0x1afb12d70c8>,
#  'grape': <gensim.models.keyedvectors.Vocab at 0x1afb12d7108>,
#  'since': <gensim.models.keyedvectors.Vocab at 0x1afb12d7148>,
#  'Ruby': <gensim.models.keyedvectors.Vocab at 0x1afb12d7188>,
#  'grapefruit': <gensim.models.keyedvectors.Vocab at 0x1afb12d71c8>,
#  'watermelon': <gensim.models.keyedvectors.Vocab at 0x1afb12d7208>,
#  'zest': <gensim.models.keyedvectors.Vocab at 0x1afb12d7248>,
#  'salty': <gensim.models.keyedvectors.Vocab at 0x1afb12d7288>,
#  'highlighted': <gensim.models.keyedvectors.Vocab at 0x1afb12d72c8>,
#  'vibrant': <gensim.models.keyedvectors.Vocab at 0x1afb12d7308>,
#  'floral': <gensim.models.keyedvectors.Vocab at 0x1afb12d7348>,
#  'Alluring': <gensim.models.keyedvectors.Vocab at 0x1afb12d7388>,
#  'powerful': <gensim.models.keyedvectors.Vocab at 0x1afb12d73c8>,
#  'grilled': <gensim.models.keyedvectors.Vocab at 0x1afb12d7408>,
#  'meat': <gensim.models.keyedvectors.Vocab at 0x1afb12d7448>,
#  'smoke': <gensim.models.keyedvectors.Vocab at 0x1afb12d7488>,
#  'cover': <gensim.models.keyedvectors.Vocab at 0x1afb12d74c8>,
#  'every': <gensim.models.keyedvectors.Vocab at 0x1afb12d7508>,
#  'base': <gensim.models.keyedvectors.Vocab at 0x1afb12d7548>,
#  'An': <gensim.models.keyedvectors.Vocab at 0x1afb12d7588>,
#  'concentrated': <gensim.models.keyedvectors.Vocab at 0x1afb12d75c8>,
#  'Blackberry': <gensim.models.keyedvectors.Vocab at 0x1afb12d7608>,
#  'molasses': <gensim.models.keyedvectors.Vocab at 0x1afb12d7648>,
#  'overall': <gensim.models.keyedvectors.Vocab at 0x1afb12d7688>,
#  'cohesion': <gensim.models.keyedvectors.Vocab at 0x1afb12d76c8>,
#  'special': <gensim.models.keyedvectors.Vocab at 0x1afb12d7708>,
#  'Rioja': <gensim.models.keyedvectors.Vocab at 0x1afb12d7748>,
#  'Tarry': <gensim.models.keyedvectors.Vocab at 0x1afb12d7788>,
#  'cheesy': <gensim.models.keyedvectors.Vocab at 0x1afb12d77c8>,
#  'appropriate': <gensim.models.keyedvectors.Vocab at 0x1afb12d7808>,
#  'size': <gensim.models.keyedvectors.Vocab at 0x1afb12d7848>,
#  'In': <gensim.models.keyedvectors.Vocab at 0x1afb12d7888>,
#  'Tinta': <gensim.models.keyedvectors.Vocab at 0x1afb12d78c8>,
#  'de': <gensim.models.keyedvectors.Vocab at 0x1afb12d7908>,
#  'expansive': <gensim.models.keyedvectors.Vocab at 0x1afb12d7948>,
#  'grabby': <gensim.models.keyedvectors.Vocab at 0x1afb12d7988>,
#  'bullish': <gensim.models.keyedvectors.Vocab at 0x1afb12d79c8>,
#  'earthy': <gensim.models.keyedvectors.Vocab at 0x1afb12d7a08>,
#  'not': <gensim.models.keyedvectors.Vocab at 0x1afb12d7a48>,
#  'too': <gensim.models.keyedvectors.Vocab at 0x1afb12d7a88>,
#  'hard': <gensim.models.keyedvectors.Vocab at 0x1afb12d7ac8>,
#  'ambitious': <gensim.models.keyedvectors.Vocab at 0x1afb12d7b08>,
#  'winery': <gensim.models.keyedvectors.Vocab at 0x1afb12d7b48>,
#  'efforts': <gensim.models.keyedvectors.Vocab at 0x1afb12d7b88>,
#  'just': <gensim.models.keyedvectors.Vocab at 0x1afb12d7bc8>,
#  'barrels': <gensim.models.keyedvectors.Vocab at 0x1afb12d7c08>,
#  'Clone': <gensim.models.keyedvectors.Vocab at 0x1afb12d7c48>,
#  'shows': <gensim.models.keyedvectors.Vocab at 0x1afb12d7c88>,
#  'focused': <gensim.models.keyedvectors.Vocab at 0x1afb12d7cc8>,
#  'nose': <gensim.models.keyedvectors.Vocab at 0x1afb12d7d08>,
#  'sizzles': <gensim.models.keyedvectors.Vocab at 0x1afb12d7d48>,
#  'saltiness': <gensim.models.keyedvectors.Vocab at 0x1afb12d7d88>,
#  'lemony': <gensim.models.keyedvectors.Vocab at 0x1afb12d7dc8>,
#  'cuts': <gensim.models.keyedvectors.Vocab at 0x1afb12d7e08>,
#  'brown': <gensim.models.keyedvectors.Vocab at 0x1afb12d7e48>,
#  'butter': <gensim.models.keyedvectors.Vocab at 0x1afb12d7e88>,
#  'luxurious': <gensim.models.keyedvectors.Vocab at 0x1afb12d7ec8>,
#  'San': <gensim.models.keyedvectors.Vocab at 0x1afb12d7f08>,
#  'based': <gensim.models.keyedvectors.Vocab at 0x1afb12d7f48>,
#  'Adam': <gensim.models.keyedvectors.Vocab at 0x1afb12d7f88>,
#  'heads': <gensim.models.keyedvectors.Vocab at 0x1afb12d7fc8>,
#  'up': <gensim.models.keyedvectors.Vocab at 0x1afb12da048>,
#  'into': <gensim.models.keyedvectors.Vocab at 0x1afb12da088>,
#  'mountains': <gensim.models.keyedvectors.Vocab at 0x1afb12da0c8>,
#  'source': <gensim.models.keyedvectors.Vocab at 0x1afb12da108>,
#  'wild': <gensim.models.keyedvectors.Vocab at 0x1afb12da148>,
#  'sage': <gensim.models.keyedvectors.Vocab at 0x1afb12da188>,
#  'eucalyptus': <gensim.models.keyedvectors.Vocab at 0x1afb12da1c8>,
#  'lead': <gensim.models.keyedvectors.Vocab at 0x1afb12da208>,
#  'followed': <gensim.models.keyedvectors.Vocab at 0x1afb12da248>,
#  'driven': <gensim.models.keyedvectors.Vocab at 0x1afb12da288>,
#  'waves': <gensim.models.keyedvectors.Vocab at 0x1afb12da2c8>,
#  'juniper': <gensim.models.keyedvectors.Vocab at 0x1afb12da308>,
#  'pine': <gensim.models.keyedvectors.Vocab at 0x1afb12da348>,
#  'bay': <gensim.models.keyedvectors.Vocab at 0x1afb12da388>,
#  'leaf': <gensim.models.keyedvectors.Vocab at 0x1afb12da3c8>,
#  'finishing': <gensim.models.keyedvectors.Vocab at 0x1afb12da408>,
#  'menthol': <gensim.models.keyedvectors.Vocab at 0x1afb12da448>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x1afb12da488>,
#  'sensation': <gensim.models.keyedvectors.Vocab at 0x1afb12da4c8>,
#  'Yields': <gensim.models.keyedvectors.Vocab at 0x1afb12da508>,
#  'were': <gensim.models.keyedvectors.Vocab at 0x1afb12da548>,
#  'intensity': <gensim.models.keyedvectors.Vocab at 0x1afb12da588>,
#  'giving': <gensim.models.keyedvectors.Vocab at 0x1afb12da5c8>,
#  'potential': <gensim.models.keyedvectors.Vocab at 0x1afb12da608>,
#  'drink': <gensim.models.keyedvectors.Vocab at 0x1afb12da648>,
#  'least': <gensim.models.keyedvectors.Vocab at 0x1afb12da688>,
#  'Hickory': <gensim.models.keyedvectors.Vocab at 0x1afb12da6c8>,
#  'before': <gensim.models.keyedvectors.Vocab at 0x1afb12da708>,
#  'ending': <gensim.models.keyedvectors.Vocab at 0x1afb12da748>,
#  'flurry': <gensim.models.keyedvectors.Vocab at 0x1afb12da788>,
#  'lime': <gensim.models.keyedvectors.Vocab at 0x1afb12da7c8>,
#  'm': <gensim.models.keyedvectors.Vocab at 0x1afb12da808>,
#  'Shea': <gensim.models.keyedvectors.Vocab at 0x1afb12da848>,
#  'designate': <gensim.models.keyedvectors.Vocab at 0x1afb12da888>,
#  'intent': <gensim.models.keyedvectors.Vocab at 0x1afb12da8c8>,
#  'showcasing': <gensim.models.keyedvectors.Vocab at 0x1afb12da908>,
#  'pretty': <gensim.models.keyedvectors.Vocab at 0x1afb12da948>,
#  'style': <gensim.models.keyedvectors.Vocab at 0x1afb12da988>,
#  'Here': <gensim.models.keyedvectors.Vocab at 0x1afb12da9c8>,
#  'lovely': <gensim.models.keyedvectors.Vocab at 0x1afb12daa08>,
#  'aromatics': <gensim.models.keyedvectors.Vocab at 0x1afb12daa48>,
#  'jelly': <gensim.models.keyedvectors.Vocab at 0x1afb12daa88>,
#  'rose': <gensim.models.keyedvectors.Vocab at 0x1afb12daac8>,
#  'petals': <gensim.models.keyedvectors.Vocab at 0x1afb12dab08>,
#  'run': <gensim.models.keyedvectors.Vocab at 0x1afb12dab48>,
#  'Streaks': <gensim.models.keyedvectors.Vocab at 0x1afb12dab88>,
#  'more': <gensim.models.keyedvectors.Vocab at 0x1afb12dabc8>,
#  'generous': <gensim.models.keyedvectors.Vocab at 0x1afb12dac08>,
#  'Focused': <gensim.models.keyedvectors.Vocab at 0x1afb12dac48>,
#  'captures': <gensim.models.keyedvectors.Vocab at 0x1afb12dac88>,
#  'essence': <gensim.models.keyedvectors.Vocab at 0x1afb12dacc8>,
#  'raspberries': <gensim.models.keyedvectors.Vocab at 0x1afb12dad08>,
#  'Aged': <gensim.models.keyedvectors.Vocab at 0x1afb12dad48>,
#  'strong': <gensim.models.keyedvectors.Vocab at 0x1afb12dad88>,
#  'vein': <gensim.models.keyedvectors.Vocab at 0x1afb12dadc8>,
#  'broaden': <gensim.models.keyedvectors.Vocab at 0x1afb12dae08>,
#  'out': <gensim.models.keyedvectors.Vocab at 0x1afb12dae48>,
#  'penetrate': <gensim.models.keyedvectors.Vocab at 0x1afb12dae88>,
#  'highlights': <gensim.models.keyedvectors.Vocab at 0x1afb12daec8>,
#  'cinnamon': <gensim.models.keyedvectors.Vocab at 0x1afb12daf08>,
#  'decant': <gensim.models.keyedvectors.Vocab at 0x1afb12daf48>,
#  'if': <gensim.models.keyedvectors.Vocab at 0x1afb12daf88>,
#  'you': <gensim.models.keyedvectors.Vocab at 0x1afb12dafc8>,
#  'want': <gensim.models.keyedvectors.Vocab at 0x1afb12dd048>,
#  'expression': <gensim.models.keyedvectors.Vocab at 0x1afb12dd088>,
#  'Cranberry': <gensim.models.keyedvectors.Vocab at 0x1afb12dd0c8>,
#  'rhubarb': <gensim.models.keyedvectors.Vocab at 0x1afb12dd108>,
#  'anise': <gensim.models.keyedvectors.Vocab at 0x1afb12dd148>,
#  'crushed': <gensim.models.keyedvectors.Vocab at 0x1afb12dd188>,
#  'slate': <gensim.models.keyedvectors.Vocab at 0x1afb12dd1c8>,
#  'show': <gensim.models.keyedvectors.Vocab at 0x1afb12dd208>,
#  'always': <gensim.models.keyedvectors.Vocab at 0x1afb12dd248>,
#  'abounds': <gensim.models.keyedvectors.Vocab at 0x1afb12dd288>,
#  'energy': <gensim.models.keyedvectors.Vocab at 0x1afb12dd2c8>,
#  'driving': <gensim.models.keyedvectors.Vocab at 0x1afb12dd308>,
#  'accented': <gensim.models.keyedvectors.Vocab at 0x1afb12dd348>,
#  'loam': <gensim.models.keyedvectors.Vocab at 0x1afb12dd388>,
#  'fennel': <gensim.models.keyedvectors.Vocab at 0x1afb12dd3c8>,
#  'oregano': <gensim.models.keyedvectors.Vocab at 0x1afb12dd408>,
#  'compellingly': <gensim.models.keyedvectors.Vocab at 0x1afb12dd448>,
#  'round': <gensim.models.keyedvectors.Vocab at 0x1afb12dd488>,
#  'Rocks': <gensim.models.keyedvectors.Vocab at 0x1afb12dd4c8>,
#  'District': <gensim.models.keyedvectors.Vocab at 0x1afb12dd508>,
#  'brings': <gensim.models.keyedvectors.Vocab at 0x1afb12dd548>,
#  'earth': <gensim.models.keyedvectors.Vocab at 0x1afb12dd588>,
#  'olive': <gensim.models.keyedvectors.Vocab at 0x1afb12dd5c8>,
#  'brine': <gensim.models.keyedvectors.Vocab at 0x1afb12dd608>,
#  'tapenade': <gensim.models.keyedvectors.Vocab at 0x1afb12dd648>,
#  'green': <gensim.models.keyedvectors.Vocab at 0x1afb12dd688>,
#  'lilies': <gensim.models.keyedvectors.Vocab at 0x1afb12dd6c8>,
#  'gravel': <gensim.models.keyedvectors.Vocab at 0x1afb12dd708>,
#  'smoked': <gensim.models.keyedvectors.Vocab at 0x1afb12dd748>,
#  'charcuterie': <gensim.models.keyedvectors.Vocab at 0x1afb12dd788>,
#  'blue': <gensim.models.keyedvectors.Vocab at 0x1afb12dd7c8>,
#  'don': <gensim.models.keyedvectors.Vocab at 0x1afb12dd808>,
#  't': <gensim.models.keyedvectors.Vocab at 0x1afb12dd848>,
#  'hold': <gensim.models.keyedvectors.Vocab at 0x1afb12dd888>,
#  'back': <gensim.models.keyedvectors.Vocab at 0x1afb12dd8c8>,
#  'bringing': <gensim.models.keyedvectors.Vocab at 0x1afb12dd908>,
#  'sense': <gensim.models.keyedvectors.Vocab at 0x1afb12dd948>,
#  'detail': <gensim.models.keyedvectors.Vocab at 0x1afb12dd988>,
#  'completely': <gensim.models.keyedvectors.Vocab at 0x1afb12dd9c8>,
#  'demands': <gensim.models.keyedvectors.Vocab at 0x1afb12dda08>,
#  'your': <gensim.models.keyedvectors.Vocab at 0x1afb12dda48>,
#  'attention': <gensim.models.keyedvectors.Vocab at 0x1afb12dda88>,
#  'Bulgarian': <gensim.models.keyedvectors.Vocab at 0x1afb12ddac8>,
#  'presents': <gensim.models.keyedvectors.Vocab at 0x1afb12ddb08>,
#  'suggestions': <gensim.models.keyedvectors.Vocab at 0x1afb12ddb48>,
#  'freshly': <gensim.models.keyedvectors.Vocab at 0x1afb12ddb88>,
#  'ground': <gensim.models.keyedvectors.Vocab at 0x1afb12ddbc8>,
#  'pepper': <gensim.models.keyedvectors.Vocab at 0x1afb12ddc08>,
#  'whiff': <gensim.models.keyedvectors.Vocab at 0x1afb12ddc48>,
#  'soft': <gensim.models.keyedvectors.Vocab at 0x1afb12ddc88>,
#  'mingling': <gensim.models.keyedvectors.Vocab at 0x1afb12ddcc8>,
#  'Steely': <gensim.models.keyedvectors.Vocab at 0x1afb12ddd08>,
#  'perfumed': <gensim.models.keyedvectors.Vocab at 0x1afb12ddd48>,
#  'sees': <gensim.models.keyedvectors.Vocab at 0x1afb12ddd88>,
#  'only': <gensim.models.keyedvectors.Vocab at 0x1afb12dddc8>,
#  'remaining': <gensim.models.keyedvectors.Vocab at 0x1afb12dde08>,
#  'vibrantly': <gensim.models.keyedvectors.Vocab at 0x1afb12dde48>,
#  'Baked': <gensim.models.keyedvectors.Vocab at 0x1afb12dde88>,
#  'apple': <gensim.models.keyedvectors.Vocab at 0x1afb12ddec8>,
#  'lemon': <gensim.models.keyedvectors.Vocab at 0x1afb12ddf08>,
#  'pith': <gensim.models.keyedvectors.Vocab at 0x1afb12ddf48>,
#  'veer': <gensim.models.keyedvectors.Vocab at 0x1afb12ddf88>,
#  'spiciness': <gensim.models.keyedvectors.Vocab at 0x1afb12ddfc8>,
#  'brash': <gensim.models.keyedvectors.Vocab at 0x1afb1432048>,
#  'loud': <gensim.models.keyedvectors.Vocab at 0x1afb1432088>,
#  'Underbrush': <gensim.models.keyedvectors.Vocab at 0x1afb14320c8>,
#  'scorched': <gensim.models.keyedvectors.Vocab at 0x1afb1432108>,
#  'steeped': <gensim.models.keyedvectors.Vocab at 0x1afb1432148>,
#  'spirits': <gensim.models.keyedvectors.Vocab at 0x1afb1432188>,
#  'some': <gensim.models.keyedvectors.Vocab at 0x1afb14321c8>,
#  'unfold': <gensim.models.keyedvectors.Vocab at 0x1afb1432208>,
#  'big': <gensim.models.keyedvectors.Vocab at 0x1afb1432248>,
#  'chewy': <gensim.models.keyedvectors.Vocab at 0x1afb1432288>,
#  'doles': <gensim.models.keyedvectors.Vocab at 0x1afb14322c8>,
#  'jam': <gensim.models.keyedvectors.Vocab at 0x1afb1432308>,
#  'alongside': <gensim.models.keyedvectors.Vocab at 0x1afb1432348>,
#  'firm': <gensim.models.keyedvectors.Vocab at 0x1afb1432388>,
#  'detect': <gensim.models.keyedvectors.Vocab at 0x1afb14323c8>,
#  'warmth': <gensim.models.keyedvectors.Vocab at 0x1afb1432408>,
#  'alcohol': <gensim.models.keyedvectors.Vocab at 0x1afb1432448>,
#  'Pale': <gensim.models.keyedvectors.Vocab at 0x1afb1432488>,
#  'nutty': <gensim.models.keyedvectors.Vocab at 0x1afb14324c8>,
#  'character': <gensim.models.keyedvectors.Vocab at 0x1afb1432508>,
#  'warm': <gensim.models.keyedvectors.Vocab at 0x1afb1432548>,
#  'rounded': <gensim.models.keyedvectors.Vocab at 0x1afb1432588>,
#  'aftertaste': <gensim.models.keyedvectors.Vocab at 0x1afb14325c8>,
#  'cellars': <gensim.models.keyedvectors.Vocab at 0x1afb1432608>,
#  'Saumur': <gensim.models.keyedvectors.Vocab at 0x1afb1432648>,
#  'Loire': <gensim.models.keyedvectors.Vocab at 0x1afb1432688>,
#  'river': <gensim.models.keyedvectors.Vocab at 0x1afb14326c8>,
#  'entice': <gensim.models.keyedvectors.Vocab at 0x1afb1432708>,
#  'wet': <gensim.models.keyedvectors.Vocab at 0x1afb1432748>,
#  'stone': <gensim.models.keyedvectors.Vocab at 0x1afb1432788>,
#  'honeysuckle': <gensim.models.keyedvectors.Vocab at 0x1afb14327c8>,
#  'chamomile': <gensim.models.keyedvectors.Vocab at 0x1afb1432808>,
#  'feel': <gensim.models.keyedvectors.Vocab at 0x1afb1432848>,
#  'showing': <gensim.models.keyedvectors.Vocab at 0x1afb1432888>,
#  'Forest': <gensim.models.keyedvectors.Vocab at 0x1afb14328c8>,
#  'floor': <gensim.models.keyedvectors.Vocab at 0x1afb1432908>,
#  'tilled': <gensim.models.keyedvectors.Vocab at 0x1afb1432948>,
#  'soil': <gensim.models.keyedvectors.Vocab at 0x1afb1432988>,
#  'combine': <gensim.models.keyedvectors.Vocab at 0x1afb14329c8>,
#  'grained': <gensim.models.keyedvectors.Vocab at 0x1afb1432a08>,
#  'grip': <gensim.models.keyedvectors.Vocab at 0x1afb1432a48>,
#  'accent': <gensim.models.keyedvectors.Vocab at 0x1afb1432a88>,
#  'melon': <gensim.models.keyedvectors.Vocab at 0x1afb1432ac8>,
#  'flabby': <gensim.models.keyedvectors.Vocab at 0x1afb1432b08>,
#  'forest': <gensim.models.keyedvectors.Vocab at 0x1afb1432b48>,
#  'violet': <gensim.models.keyedvectors.Vocab at 0x1afb1432b88>,
#  'star': <gensim.models.keyedvectors.Vocab at 0x1afb1432bc8>,
#  'drive': <gensim.models.keyedvectors.Vocab at 0x1afb1432c08>,
#  'classic': <gensim.models.keyedvectors.Vocab at 0x1afb1432c48>,
#  'Tuscan': <gensim.models.keyedvectors.Vocab at 0x1afb1432c88>,
#  'charming': <gensim.models.keyedvectors.Vocab at 0x1afb1432cc8>,
#  'boasts': <gensim.models.keyedvectors.Vocab at 0x1afb1432d08>,
#  'easy': <gensim.models.keyedvectors.Vocab at 0x1afb1432d48>,
#  'chopped': <gensim.models.keyedvectors.Vocab at 0x1afb1432d88>,
#  'mint': <gensim.models.keyedvectors.Vocab at 0x1afb1432dc8>,
#  'There': <gensim.models.keyedvectors.Vocab at 0x1afb1432e08>,
#  'isn': <gensim.models.keyedvectors.Vocab at 0x1afb1432e48>,
#  'much': <gensim.models.keyedvectors.Vocab at 0x1afb1432e88>,
#  'delivers': <gensim.models.keyedvectors.Vocab at 0x1afb1432ec8>,
#  'Polished': <gensim.models.keyedvectors.Vocab at 0x1afb1432f08>,
#  'provide': <gensim.models.keyedvectors.Vocab at 0x1afb1432f48>,
#  'framework': <gensim.models.keyedvectors.Vocab at 0x1afb1432f88>,
#  'Earthy': <gensim.models.keyedvectors.Vocab at 0x1afb1432fc8>,
#  'score': <gensim.models.keyedvectors.Vocab at 0x1afb1435048>,
#  'points': <gensim.models.keyedvectors.Vocab at 0x1afb1435088>,
#  'being': <gensim.models.keyedvectors.Vocab at 0x1afb14350c8>,
#  'clear': <gensim.models.keyedvectors.Vocab at 0x1afb1435108>,
#  'direct': <gensim.models.keyedvectors.Vocab at 0x1afb1435148>,
#  'Menc': <gensim.models.keyedvectors.Vocab at 0x1afb1435188>,
#  'Lightly': <gensim.models.keyedvectors.Vocab at 0x1afb14351c8>,
#  'briny': <gensim.models.keyedvectors.Vocab at 0x1afb1435208>,
#  'steady': <gensim.models.keyedvectors.Vocab at 0x1afb1435248>,
#  'dash': <gensim.models.keyedvectors.Vocab at 0x1afb1435288>,
#  'comes': <gensim.models.keyedvectors.Vocab at 0x1afb14352c8>,
#  'across': <gensim.models.keyedvectors.Vocab at 0x1afb1435308>,
#  'wide': <gensim.models.keyedvectors.Vocab at 0x1afb1435348>,
#  'exudes': <gensim.models.keyedvectors.Vocab at 0x1afb1435388>,
#  'oily': <gensim.models.keyedvectors.Vocab at 0x1afb14353c8>,
#  'toffee': <gensim.models.keyedvectors.Vocab at 0x1afb1435408>,
#  'plump': <gensim.models.keyedvectors.Vocab at 0x1afb1435448>,
#  'overly': <gensim.models.keyedvectors.Vocab at 0x1afb1435488>,
#  'cutting': <gensim.models.keyedvectors.Vocab at 0x1afb14354c8>,
#  'demanding': <gensim.models.keyedvectors.Vocab at 0x1afb1435508>,
#  'lightly': <gensim.models.keyedvectors.Vocab at 0x1afb1435548>,
#  'salted': <gensim.models.keyedvectors.Vocab at 0x1afb1435588>,
#  'nuts': <gensim.models.keyedvectors.Vocab at 0x1afb14355c8>,
#  'buttered': <gensim.models.keyedvectors.Vocab at 0x1afb1435608>,
#  'end': <gensim.models.keyedvectors.Vocab at 0x1afb1435648>,
#  'peanut': <gensim.models.keyedvectors.Vocab at 0x1afb1435688>,
#  'flowers': <gensim.models.keyedvectors.Vocab at 0x1afb14356c8>,
#  'herbs': <gensim.models.keyedvectors.Vocab at 0x1afb1435708>,
#  'tightly': <gensim.models.keyedvectors.Vocab at 0x1afb1435748>,
#  'coiled': <gensim.models.keyedvectors.Vocab at 0x1afb1435788>,
#  'acids': <gensim.models.keyedvectors.Vocab at 0x1afb14357c8>,
#  'pleasing': <gensim.models.keyedvectors.Vocab at 0x1afb1435808>,
#  'example': <gensim.models.keyedvectors.Vocab at 0x1afb1435848>,
#  'variety': <gensim.models.keyedvectors.Vocab at 0x1afb1435888>,
#  'skinned': <gensim.models.keyedvectors.Vocab at 0x1afb14358c8>,
#  'clove': <gensim.models.keyedvectors.Vocab at 0x1afb1435908>,
#  'profile': <gensim.models.keyedvectors.Vocab at 0x1afb1435948>,
#  'Cornas': <gensim.models.keyedvectors.Vocab at 0x1afb1435988>,
#  'reminiscent': <gensim.models.keyedvectors.Vocab at 0x1afb14359c8>,
#  'fudge': <gensim.models.keyedvectors.Vocab at 0x1afb1435a08>,
#  'plummy': <gensim.models.keyedvectors.Vocab at 0x1afb1435a48>,
#  'dusty': <gensim.models.keyedvectors.Vocab at 0x1afb1435a88>,
#  'blend': <gensim.models.keyedvectors.Vocab at 0x1afb1435ac8>,
# ...
#  'support': <gensim.models.keyedvectors.Vocab at 0x1afb1435bc8>,
#  'meld': <gensim.models.keyedvectors.Vocab at 0x1afb1435c08>,
#  'Blended': <gensim.models.keyedvectors.Vocab at 0x1afb1435c48>,
#  'Malbec': <gensim.models.keyedvectors.Vocab at 0x1afb1435c88>,
#  'Cabernet': <gensim.models.keyedvectors.Vocab at 0x1afb1435cc8>,
#  'Franc': <gensim.models.keyedvectors.Vocab at 0x1afb1435d08>,
#  'Petit': <gensim.models.keyedvectors.Vocab at 0x1afb1435d48>,
#  'Verdot': <gensim.models.keyedvectors.Vocab at 0x1afb1435d88>,
#  'perennial': <gensim.models.keyedvectors.Vocab at 0x1afb1435dc8>,
#  'sister': <gensim.models.keyedvectors.Vocab at 0x1afb1435e08>,
#  'brand': <gensim.models.keyedvectors.Vocab at 0x1afb1435e48>,
#  'Cuvaison': <gensim.models.keyedvectors.Vocab at 0x1afb1435e88>,
#  'pillowy': <gensim.models.keyedvectors.Vocab at 0x1afb1435ec8>,
#  'tar': <gensim.models.keyedvectors.Vocab at 0x1afb1435f08>,
#  'suggesting': <gensim.models.keyedvectors.Vocab at 0x1afb1435f48>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x1afb1435f88>,
#  'match': <gensim.models.keyedvectors.Vocab at 0x1afb1435fc8>,
#  'cooking': <gensim.models.keyedvectors.Vocab at 0x1afb1438048>,
#  'accessible': <gensim.models.keyedvectors.Vocab at 0x1afb1438088>,
#  'so': <gensim.models.keyedvectors.Vocab at 0x1afb14380c8>,
#  'no': <gensim.models.keyedvectors.Vocab at 0x1afb1438108>,
#  'need': <gensim.models.keyedvectors.Vocab at 0x1afb1438148>,
#  'Best': <gensim.models.keyedvectors.Vocab at 0x1afb1438188>,
#  'initially': <gensim.models.keyedvectors.Vocab at 0x1afb14381c8>,
#  'under': <gensim.models.keyedvectors.Vocab at 0x1afb1438208>,
#  'tight': <gensim.models.keyedvectors.Vocab at 0x1afb1438248>,
#  'simultaneously': <gensim.models.keyedvectors.Vocab at 0x1afb1438288>,
#  'robust': <gensim.models.keyedvectors.Vocab at 0x1afb14382c8>,
#  'cake': <gensim.models.keyedvectors.Vocab at 0x1afb1438308>,
#  'hearty': <gensim.models.keyedvectors.Vocab at 0x1afb1438348>,
#  'closes': <gensim.models.keyedvectors.Vocab at 0x1afb1438388>,
#  'structured': <gensim.models.keyedvectors.Vocab at 0x1afb14383c8>,
#  'weight': <gensim.models.keyedvectors.Vocab at 0x1afb1438408>,
#  'almost': <gensim.models.keyedvectors.Vocab at 0x1afb1438448>,
#  'will': <gensim.models.keyedvectors.Vocab at 0x1afb1438488>,
#  'soften': <gensim.models.keyedvectors.Vocab at 0x1afb14384c8>,
#  'next': <gensim.models.keyedvectors.Vocab at 0x1afb1438508>,
#  'few': <gensim.models.keyedvectors.Vocab at 0x1afb1438548>,
#  'Full': <gensim.models.keyedvectors.Vocab at 0x1afb1438588>,
#  'drinkable': <gensim.models.keyedvectors.Vocab at 0x1afb14385c8>,
#  'be': <gensim.models.keyedvectors.Vocab at 0x1afb1438608>,
#  'better': <gensim.models.keyedvectors.Vocab at 0x1afb1438648>,
#  'lifted': <gensim.models.keyedvectors.Vocab at 0x1afb1438688>,
#  'richer': <gensim.models.keyedvectors.Vocab at 0x1afb14386c8>,
#  'apricot': <gensim.models.keyedvectors.Vocab at 0x1afb1438708>,
#  'Still': <gensim.models.keyedvectors.Vocab at 0x1afb1438748>,
#  'young': <gensim.models.keyedvectors.Vocab at 0x1afb1438788>,
#  'going': <gensim.models.keyedvectors.Vocab at 0x1afb14387c8>,
#  'fruity': <gensim.models.keyedvectors.Vocab at 0x1afb1438808>,
#  'name': <gensim.models.keyedvectors.Vocab at 0x1afb1438848>,
#  'means': <gensim.models.keyedvectors.Vocab at 0x1afb1438888>,
#  'parcel': <gensim.models.keyedvectors.Vocab at 0x1afb14388c8>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x1afb1438908>,
#  'day': <gensim.models.keyedvectors.Vocab at 0x1afb1438948>,
#  'light': <gensim.models.keyedvectors.Vocab at 0x1afb1438988>,
#  'smoky': <gensim.models.keyedvectors.Vocab at 0x1afb14389c8>,
#  'slowly': <gensim.models.keyedvectors.Vocab at 0x1afb1438a08>,
#  'lot': <gensim.models.keyedvectors.Vocab at 0x1afb1438a48>,
#  'priced': <gensim.models.keyedvectors.Vocab at 0x1afb1438a88>,
#  'several': <gensim.models.keyedvectors.Vocab at 0x1afb1438ac8>,
#  'regional': <gensim.models.keyedvectors.Vocab at 0x1afb1438b08>,
#  'taste': <gensim.models.keyedvectors.Vocab at 0x1afb1438b48>,
#  'expands': <gensim.models.keyedvectors.Vocab at 0x1afb1438b88>,
#  'meet': <gensim.models.keyedvectors.Vocab at 0x1afb1438bc8>,
#  'crowd': <gensim.models.keyedvectors.Vocab at 0x1afb1438c08>,
#  'measured': <gensim.models.keyedvectors.Vocab at 0x1afb1438c48>,
#  'Grand': <gensim.models.keyedvectors.Vocab at 0x1afb1438c88>,
#  'Ciel': <gensim.models.keyedvectors.Vocab at 0x1afb1438cc8>,
#  'du': <gensim.models.keyedvectors.Vocab at 0x1afb1438d08>,
#  'Cheval': <gensim.models.keyedvectors.Vocab at 0x1afb1438d48>,
#  'Klipsun': <gensim.models.keyedvectors.Vocab at 0x1afb1438d88>,
#  'front': <gensim.models.keyedvectors.Vocab at 0x1afb1438dc8>,
#  'Delicious': <gensim.models.keyedvectors.Vocab at 0x1afb1438e08>,
#  'biodynamically': <gensim.models.keyedvectors.Vocab at 0x1afb1438e48>,
#  'grown': <gensim.models.keyedvectors.Vocab at 0x1afb1438e88>,
#  'grapes': <gensim.models.keyedvectors.Vocab at 0x1afb1438ec8>,
#  'moment': <gensim.models.keyedvectors.Vocab at 0x1afb1438f08>,
#  'needs': <gensim.models.keyedvectors.Vocab at 0x1afb1438f48>,
#  'While': <gensim.models.keyedvectors.Vocab at 0x1afb1438f88>,
#  'exuberantly': <gensim.models.keyedvectors.Vocab at 0x1afb1438fc8>,
#  'tropical': <gensim.models.keyedvectors.Vocab at 0x1afb143b048>,
#  'crystalline': <gensim.models.keyedvectors.Vocab at 0x1afb143b088>,
#  'edge': <gensim.models.keyedvectors.Vocab at 0x1afb143b0c8>,
#  'dry': <gensim.models.keyedvectors.Vocab at 0x1afb143b108>,
#  'Riesling': <gensim.models.keyedvectors.Vocab at 0x1afb143b148>,
#  'renders': <gensim.models.keyedvectors.Vocab at 0x1afb143b188>,
#  'especially': <gensim.models.keyedvectors.Vocab at 0x1afb143b1c8>,
#  'refreshing': <gensim.models.keyedvectors.Vocab at 0x1afb143b208>,
#  'footed': <gensim.models.keyedvectors.Vocab at 0x1afb143b248>,
#  'brightened': <gensim.models.keyedvectors.Vocab at 0x1afb143b288>,
#  'honey': <gensim.models.keyedvectors.Vocab at 0x1afb143b2c8>,
#  'half': <gensim.models.keyedvectors.Vocab at 0x1afb143b308>,
#  'cherries': <gensim.models.keyedvectors.Vocab at 0x1afb143b348>,
#  'minerals': <gensim.models.keyedvectors.Vocab at 0x1afb143b388>,
#  'plush': <gensim.models.keyedvectors.Vocab at 0x1afb143b3c8>,
#  'feeling': <gensim.models.keyedvectors.Vocab at 0x1afb143b408>,
#  'backed': <gensim.models.keyedvectors.Vocab at 0x1afb143b448>,
#  'Merlot': <gensim.models.keyedvectors.Vocab at 0x1afb143b488>,
#  'Sauvignon': <gensim.models.keyedvectors.Vocab at 0x1afb143b4c8>,
#  'Syrah': <gensim.models.keyedvectors.Vocab at 0x1afb143b508>,
#  'roasted': <gensim.models.keyedvectors.Vocab at 0x1afb143b548>,
#  'bean': <gensim.models.keyedvectors.Vocab at 0x1afb143b588>,
#  'woodland': <gensim.models.keyedvectors.Vocab at 0x1afb143b5c8>,
#  'Concentrated': <gensim.models.keyedvectors.Vocab at 0x1afb143b608>,
#  'heat': <gensim.models.keyedvectors.Vocab at 0x1afb143b648>,
#  'lends': <gensim.models.keyedvectors.Vocab at 0x1afb143b688>,
#  'sizzle': <gensim.models.keyedvectors.Vocab at 0x1afb143b6c8>,
#  'estate': <gensim.models.keyedvectors.Vocab at 0x1afb143b708>,
#  'Pinot': <gensim.models.keyedvectors.Vocab at 0x1afb143b748>,
#  'Noir': <gensim.models.keyedvectors.Vocab at 0x1afb143b788>,
#  'solid': <gensim.models.keyedvectors.Vocab at 0x1afb143b7c8>,
#  'value': <gensim.models.keyedvectors.Vocab at 0x1afb143b808>,
#  'boutique': <gensim.models.keyedvectors.Vocab at 0x1afb143b848>,
#  'offerings': <gensim.models.keyedvectors.Vocab at 0x1afb143b888>,
#  'cushioning': <gensim.models.keyedvectors.Vocab at 0x1afb143b8c8>,
#  'flesh': <gensim.models.keyedvectors.Vocab at 0x1afb143b908>,
#  'wrapped': <gensim.models.keyedvectors.Vocab at 0x1afb143b948>,
#  'around': <gensim.models.keyedvectors.Vocab at 0x1afb143b988>,
#  'backbone': <gensim.models.keyedvectors.Vocab at 0x1afb143b9c8>,
#  'earthier': <gensim.models.keyedvectors.Vocab at 0x1afb143ba08>,
#  'parsnip': <gensim.models.keyedvectors.Vocab at 0x1afb143ba48>,
#  'Smoky': <gensim.models.keyedvectors.Vocab at 0x1afb143ba88>,
#  'cut': <gensim.models.keyedvectors.Vocab at 0x1afb143bac8>,
#  'form': <gensim.models.keyedvectors.Vocab at 0x1afb143bb08>,
#  'welcoming': <gensim.models.keyedvectors.Vocab at 0x1afb143bb48>,
#  'bouquet': <gensim.models.keyedvectors.Vocab at 0x1afb143bb88>,
#  'albeit': <gensim.models.keyedvectors.Vocab at 0x1afb143bbc8>,
#  'tartaric': <gensim.models.keyedvectors.Vocab at 0x1afb143bc08>,
#  'Oaky': <gensim.models.keyedvectors.Vocab at 0x1afb143bc48>,
#  'agreeable': <gensim.models.keyedvectors.Vocab at 0x1afb143bc88>,
#  'northern': <gensim.models.keyedvectors.Vocab at 0x1afb143bcc8>,
#  'Fourchaume': <gensim.models.keyedvectors.Vocab at 0x1afb143bd08>,
#  'Premier': <gensim.models.keyedvectors.Vocab at 0x1afb143bd48>,
#  'Cru': <gensim.models.keyedvectors.Vocab at 0x1afb143bd88>,
#  'called': <gensim.models.keyedvectors.Vocab at 0x1afb143bdc8>,
#  'because': <gensim.models.keyedvectors.Vocab at 0x1afb143be08>,
#  'where': <gensim.models.keyedvectors.Vocab at 0x1afb143be48>,
#  'local': <gensim.models.keyedvectors.Vocab at 0x1afb143be88>,
#  'justice': <gensim.models.keyedvectors.Vocab at 0x1afb143bec8>,
#  'often': <gensim.models.keyedvectors.Vocab at 0x1afb143bf08>,
#  'produces': <gensim.models.keyedvectors.Vocab at 0x1afb143bf48>,
#  'cooler': <gensim.models.keyedvectors.Vocab at 0x1afb143bf88>,
#  'wines': <gensim.models.keyedvectors.Vocab at 0x1afb143bfc8>,
#  'such': <gensim.models.keyedvectors.Vocab at 0x1afb1440048>,
#  'bread': <gensim.models.keyedvectors.Vocab at 0x1afb1440088>,
#  'strongly': <gensim.models.keyedvectors.Vocab at 0x1afb14400c8>,
#  'does': <gensim.models.keyedvectors.Vocab at 0x1afb1440108>,
#  'shouldn': <gensim.models.keyedvectors.Vocab at 0x1afb1440148>,
#  'drunk': <gensim.models.keyedvectors.Vocab at 0x1afb1440188>,
#  'super': <gensim.models.keyedvectors.Vocab at 0x1afb14401c8>,
#  'very': <gensim.models.keyedvectors.Vocab at 0x1afb1440208>,
#  'allow': <gensim.models.keyedvectors.Vocab at 0x1afb1440248>,
#  'age': <gensim.models.keyedvectors.Vocab at 0x1afb1440288>,
#  'combination': <gensim.models.keyedvectors.Vocab at 0x1afb14402c8>,
#  'skin': <gensim.models.keyedvectors.Vocab at 0x1afb1440308>,
#  'leave': <gensim.models.keyedvectors.Vocab at 0x1afb1440348>,
#  'until': <gensim.models.keyedvectors.Vocab at 0x1afb1440388>,
#  'Fresh': <gensim.models.keyedvectors.Vocab at 0x1afb14403c8>,
#  'boysenberries': <gensim.models.keyedvectors.Vocab at 0x1afb1440408>,
#  'sorbet': <gensim.models.keyedvectors.Vocab at 0x1afb1440448>,
#  'tarragon': <gensim.models.keyedvectors.Vocab at 0x1afb1440488>,
#  'dill': <gensim.models.keyedvectors.Vocab at 0x1afb14404c8>,
#  'hot': <gensim.models.keyedvectors.Vocab at 0x1afb1440508>,
#  'area': <gensim.models.keyedvectors.Vocab at 0x1afb1440548>,
#  'between': <gensim.models.keyedvectors.Vocab at 0x1afb1440588>,
#  'Morgan': <gensim.models.keyedvectors.Vocab at 0x1afb14405c8>,
#  'Hill': <gensim.models.keyedvectors.Vocab at 0x1afb1440608>,
#  'prominent': <gensim.models.keyedvectors.Vocab at 0x1afb1440648>,
#  'relatively': <gensim.models.keyedvectors.Vocab at 0x1afb1440688>,
#  'boysenberry': <gensim.models.keyedvectors.Vocab at 0x1afb14406c8>,
#  'steely': <gensim.models.keyedvectors.Vocab at 0x1afb1440708>,
#  'Chablis': <gensim.models.keyedvectors.Vocab at 0x1afb1440748>,
#  'apparent': <gensim.models.keyedvectors.Vocab at 0x1afb1440788>,
#  'flavored': <gensim.models.keyedvectors.Vocab at 0x1afb14407c8>,
#  'freshness': <gensim.models.keyedvectors.Vocab at 0x1afb1440808>,
#  'heart': <gensim.models.keyedvectors.Vocab at 0x1afb1440848>,
#  'needing': <gensim.models.keyedvectors.Vocab at 0x1afb1440888>,
#  'monumental': <gensim.models.keyedvectors.Vocab at 0x1afb14408c8>,
#  'Atlas': <gensim.models.keyedvectors.Vocab at 0x1afb1440908>,
#  'Peak': <gensim.models.keyedvectors.Vocab at 0x1afb1440948>,
#  'wound': <gensim.models.keyedvectors.Vocab at 0x1afb1440988>,
#  'solidly': <gensim.models.keyedvectors.Vocab at 0x1afb14409c8>,
#  'constructed': <gensim.models.keyedvectors.Vocab at 0x1afb1440a08>,
#  'mountain': <gensim.models.keyedvectors.Vocab at 0x1afb1440a48>,
#  'Cab': <gensim.models.keyedvectors.Vocab at 0x1afb1440a88>,
#  'blended': <gensim.models.keyedvectors.Vocab at 0x1afb1440ac8>,
#  'handful': <gensim.models.keyedvectors.Vocab at 0x1afb1440b08>,
#  'Tobacco': <gensim.models.keyedvectors.Vocab at 0x1afb1440b48>,
#  'sliver': <gensim.models.keyedvectors.Vocab at 0x1afb1440b88>,
#  'coconut': <gensim.models.keyedvectors.Vocab at 0x1afb1440bc8>,
#  'intermingle': <gensim.models.keyedvectors.Vocab at 0x1afb1440c08>,
#  'whole': <gensim.models.keyedvectors.Vocab at 0x1afb1440c48>,
#  'benefit': <gensim.models.keyedvectors.Vocab at 0x1afb1440c88>,
#  'cellaring': <gensim.models.keyedvectors.Vocab at 0x1afb1440cc8>,
#  'Big': <gensim.models.keyedvectors.Vocab at 0x1afb1440d08>,
#  'bold': <gensim.models.keyedvectors.Vocab at 0x1afb1440d48>,
#  'builds': <gensim.models.keyedvectors.Vocab at 0x1afb1440d88>,
#  'upon': <gensim.models.keyedvectors.Vocab at 0x1afb1440dc8>,
#  'substantial': <gensim.models.keyedvectors.Vocab at 0x1afb1440e08>,
#  'supporting': <gensim.models.keyedvectors.Vocab at 0x1afb1440e48>,
#  'knitting': <gensim.models.keyedvectors.Vocab at 0x1afb1440e88>,
#  'thick': <gensim.models.keyedvectors.Vocab at 0x1afb1440ec8>,
#  'Give': <gensim.models.keyedvectors.Vocab at 0x1afb1440f08>,
#  'couple': <gensim.models.keyedvectors.Vocab at 0x1afb1440f48>,
#  'bottle': <gensim.models.keyedvectors.Vocab at 0x1afb1440f88>,
#  'juiciness': <gensim.models.keyedvectors.Vocab at 0x1afb1440fc8>,
#  'spark': <gensim.models.keyedvectors.Vocab at 0x1afb1443048>,
#  'celebration': <gensim.models.keyedvectors.Vocab at 0x1afb1443088>,
#  'vintage': <gensim.models.keyedvectors.Vocab at 0x1afb14430c8>,
#  'appellation': <gensim.models.keyedvectors.Vocab at 0x1afb1443108>,
#  'case': <gensim.models.keyedvectors.Vocab at 0x1afb1443148>,
#  'forwardness': <gensim.models.keyedvectors.Vocab at 0x1afb1443188>,
#  'highlight': <gensim.models.keyedvectors.Vocab at 0x1afb14431c8>,
#  'depth': <gensim.models.keyedvectors.Vocab at 0x1afb1443208>,
#  'small': <gensim.models.keyedvectors.Vocab at 0x1afb1443248>,
#  'amounts': <gensim.models.keyedvectors.Vocab at 0x1afb1443288>,
#  'Soft': <gensim.models.keyedvectors.Vocab at 0x1afb14432c8>,
#  'crafts': <gensim.models.keyedvectors.Vocab at 0x1afb1443308>,
#  'draws': <gensim.models.keyedvectors.Vocab at 0x1afb1443348>,
#  'sites': <gensim.models.keyedvectors.Vocab at 0x1afb1443388>,
#  'including': <gensim.models.keyedvectors.Vocab at 0x1afb14433c8>,
#  'Ranch': <gensim.models.keyedvectors.Vocab at 0x1afb1443408>,
#  'climate': <gensim.models.keyedvectors.Vocab at 0x1afb1443448>,
#  'minimally': <gensim.models.keyedvectors.Vocab at 0x1afb1443488>,
#  'sun': <gensim.models.keyedvectors.Vocab at 0x1afb14434c8>,
#  'marinated': <gensim.models.keyedvectors.Vocab at 0x1afb1443508>,
#  'game': <gensim.models.keyedvectors.Vocab at 0x1afb1443548>,
#  'Massively': <gensim.models.keyedvectors.Vocab at 0x1afb1443588>,
#  'huge': <gensim.models.keyedvectors.Vocab at 0x1afb14435c8>,
#  'convey': <gensim.models.keyedvectors.Vocab at 0x1afb1443608>,
#  'impression': <gensim.models.keyedvectors.Vocab at 0x1afb1443648>,
#  'sweetness': <gensim.models.keyedvectors.Vocab at 0x1afb1443688>,
#  'off': <gensim.models.keyedvectors.Vocab at 0x1afb14436c8>,
#  'Alicante': <gensim.models.keyedvectors.Vocab at 0x1afb1443708>,
#  'Bouschet': <gensim.models.keyedvectors.Vocab at 0x1afb1443748>,
#  'dominates': <gensim.models.keyedvectors.Vocab at 0x1afb1443788>,
#  'firmly': <gensim.models.keyedvectors.Vocab at 0x1afb14437c8>,
#  'hugely': <gensim.models.keyedvectors.Vocab at 0x1afb1443808>,
#  'Wait': <gensim.models.keyedvectors.Vocab at 0x1afb1443848>,
#  'different': <gensim.models.keyedvectors.Vocab at 0x1afb1443888>,
#  'widely': <gensim.models.keyedvectors.Vocab at 0x1afb14438c8>,
#  'available': <gensim.models.keyedvectors.Vocab at 0x1afb1443908>,
#  'cuv': <gensim.models.keyedvectors.Vocab at 0x1afb1443948>,
#  'e': <gensim.models.keyedvectors.Vocab at 0x1afb1443988>,
#  'sturdy': <gensim.models.keyedvectors.Vocab at 0x1afb14439c8>,
#  'currant': <gensim.models.keyedvectors.Vocab at 0x1afb1443a08>,
#  'would': <gensim.models.keyedvectors.Vocab at 0x1afb1443a48>,
#  'ideal': <gensim.models.keyedvectors.Vocab at 0x1afb1443a88>,
#  ...}

# %%
print(wine2vec.corpus_count)
# Out:
# 266254

# %%
wine2vec.train(sentences, total_examples=wine2vec.corpus_count, epochs=wine2vec.iter)
# Out:
# C:\Users\Threadripper\anaconda3\envs\winereviews\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `iter` (Attribute will be removed in 4.0.0, use self.epochs instead).
#   """Entry point for launching an IPython kernel.
# (22314634, 30973815)

# %%
wine2vec.most_similar('melon')
# Out:
# C:\Users\Threadripper\anaconda3\envs\winereviews\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('nectarine', 0.6714903116226196),
#  ('peach', 0.6369867324829102),
#  ('papaya', 0.6004971265792847),
#  ('cantaloupe', 0.5980613827705383),
#  ('passion', 0.5918236970901489),
#  ('pear', 0.5785303115844727),
#  ('fuzz', 0.5783164501190186),
#  ('Melon', 0.5735518932342529),
#  ('Petrol', 0.5687561631202698),
#  ('canteloupe', 0.5640507936477661)]

# %%
wine2vec.most_similar('bad')
# Out:
# C:\Users\Threadripper\anaconda3\envs\winereviews\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('awful', 0.5221390724182129),
#  ('horrible', 0.5130788087844849),
#  ('inappropriate', 0.5070090293884277),
#  ('se', 0.500730037689209),
#  ('overpriced', 0.5002012252807617),
#  ('terrible', 0.49675774574279785),
#  ('disaster', 0.4957996904850006),
#  ('unattractive', 0.4917920231819153),
#  ('Plus', 0.4725416302680969),
#  ('purposes', 0.4697968661785126)]

# %%
wine2vec.most_similar('oak')

# %%
wine2vec.most_similar('acidic')

# %%
wine2vec.most_similar('full')

# %%
wine2vec.most_similar('tannins')

# %%
def nearest_similarity_cosmul(start1, end1, end2):
    similarities = wine2vec.most_similar_cosmul(
        positive=[end2, start1],
        negative=[end1]
    )
    start2 = similarities[0][0]
    print("{start1} is related to {end1}, as {start2} is related to {end2}".format(**locals()))
    return start2

# %%
nearest_similarity_cosmul('oak', 'vanilla', 'cherry');

# %%
nearest_similarity_cosmul('full', 'berry', 'light');

# %%
nearest_similarity_cosmul('tannins', 'plum', 'fresh');

# %%
nearest_similarity_cosmul('full', 'bodied', 'acidic');

# %%
wine2vec.most_similar('sweetness')

# %%
wine2vec.most_similar('alcohol')

# %%
wine2vec.most_similar('aromas')

# %%
wine2vec.most_similar('gumdrop')
